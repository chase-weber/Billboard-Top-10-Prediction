# %% [markdown]
# ## 0. Import Packages and Data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.linear_model import LogisticRegression
# import pycaret below <- automates the expiramentation process (test KNN, test logistic, etc...)
from pycaret.regression import setup, compare_models, create_model

# from pycaret.classification import setup
# from pycaret.classification import compare_models

# %%
# Import data that was output from previous notebook "2. Exploratory Data Analysis"
df = pd.read_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/df_emo_full_eda.csv', index_col = 0)

# %%
# Check that the details of this dataset make sense.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327895 entries, 0 to 327894
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WeekID                       327895 non-null  object
#  1   Week Position                327895 non-null  int64
#  2   Song                         327895 non-null  object
#  3   SongID                       327895 non-null  object
#  4   Instance                     327895 non-null  int64
#  5   Previous Week Position       327895 non-null  float64
#  6   Peak Position                327895 non-null  int64
#  7   Weeks on Chart               327895 non-null  int64
#  8   Artist                       269355 non-null  object
#  9   wordCount                    327895 non-null  float64
#  10  languages                    269355 non-null  object
#  11  allWordCount                 327895 non-null  float64
#  12  year                         327895 non-null  float64
#  13  decade                       327895 non-null  object
#  14  MTLD                         327895 non-null  float64
#  15  TTR                          327895 non-null  float64
#  16  CTTR                         327895 non-null  float64
#  17  sentimentScore               327895 non-null  float64
#  18  sentimentScore_pos           327895 non-null  float64
#  19  sentimentScore_neg           327895 non-null  float64
#  20  emoWordCount                 327895 non-null  float64
#  21  joy_normalized               327895 non-null  float64
#  22  sadness_normalized           327895 non-null  float64
#  23  anger_normalized             327895 non-null  float64
#  24  disgust_normalized           327895 non-null  float64
#  25  trust_normalized             327895 non-null  float64
#  26  anticipation_normalized      327895 non-null  float64
#  27  fear_normalized              327895 non-null  float64
#  28  surprise_normalized          327895 non-null  float64
#  29  emo_score                    327895 non-null  float64
#  30  happy_normalized             327895 non-null  float64
#  31  sorrow_normalized            327895 non-null  float64
#  32  YearID                       327895 non-null  int64
#  33  DecadeID                     327895 non-null  object
#  34  SuccessInd                   327895 non-null  int64
#  35  PrimaryKey                   327895 non-null  object
#  36  Week_dt                      327895 non-null  object
#  37  Week_dt_next                 327895 non-null  object
#  38  YearID_next                  327895 non-null  int64
#  39  Artist_Count_Total           269355 non-null  float64
#  40  Artist_Count_Year            269355 non-null  float64
#  41  Artist_Count_Year_prior      161594 non-null  float64
#  42  Artist_Count_Week            269355 non-null  float64
#  43  Artist_Count_Week_prior      250371 non-null  float64
#  44  joy_normalized_ind           327895 non-null  int64
#  45  sadness_normalized_ind       327895 non-null  int64
#  46  anger_normalized_ind         327895 non-null  int64
#  47  disgust_normalized_ind       327895 non-null  int64
#  48  trust_normalized_ind         327895 non-null  int64
#  49  anticipation_normalized_ind  327895 non-null  int64
#  50  fear_normalized_ind          327895 non-null  int64
#  51  surprise_normalized_ind      327895 non-null  int64
#  52  happy_normalized_ind         327895 non-null  int64
#  53  sorrow_normalized_ind        327895 non-null  int64
# dtypes: float64(27), int64(17), object(10)
# memory usage: 137.6+ MB

# %% [markdown]
# From the above, it appears that "decade" is the only object variable that needs to be transformed for modeling. All others objects, such as Week, SongID, and Artist are index related.

# %%
# Convert Decade Object Variable to Dummies
decade_dummies = pd.get_dummies(df['decade'])
df.drop("decade", axis = 1, inplace = True)
df = df.join(decade_dummies)

# %%
#Check that the Decade dummies are as expected
df.dtypes
# Out:
# WeekID                          object
# Week Position                    int64
# Song                            object
# SongID                          object
# Instance                         int64
# Previous Week Position         float64
# Peak Position                    int64
# Weeks on Chart                   int64
# Artist                          object
# wordCount                      float64
# languages                       object
# allWordCount                   float64
# year                           float64
# MTLD                           float64
# TTR                            float64
# CTTR                           float64
# sentimentScore                 float64
# sentimentScore_pos             float64
# sentimentScore_neg             float64
# emoWordCount                   float64
# joy_normalized                 float64
# sadness_normalized             float64
# anger_normalized               float64
# disgust_normalized             float64
# trust_normalized               float64
# anticipation_normalized        float64
# fear_normalized                float64
# surprise_normalized            float64
# emo_score                      float64
# happy_normalized               float64
# sorrow_normalized              float64
# YearID                           int64
# DecadeID                        object
# SuccessInd                       int64
# PrimaryKey                      object
# Week_dt                         object
# Week_dt_next                    object
# YearID_next                      int64
# Artist_Count_Total             float64
# Artist_Count_Year              float64
# Artist_Count_Year_prior        float64
# Artist_Count_Week              float64
# Artist_Count_Week_prior        float64
# joy_normalized_ind               int64
# sadness_normalized_ind           int64
# anger_normalized_ind             int64
# disgust_normalized_ind           int64
# trust_normalized_ind             int64
# anticipation_normalized_ind      int64
# fear_normalized_ind              int64
# surprise_normalized_ind          int64
# happy_normalized_ind             int64
# sorrow_normalized_ind            int64
# 00s                              uint8
# 10s                              uint8
# 20s                              uint8
# 50s                              uint8
# 60s                              uint8
# 70s                              uint8
# 80s                              uint8
# 90s                              uint8
# dtype: object

# %%
# Remove unnecessary columns, particularly the columns we are not interested in using.
df.drop(columns = ['joy_normalized', 'sadness_normalized', 'anger_normalized', 'disgust_normalized', 'trust_normalized', 'anticipation_normalized', 'fear_normalized', 'surprise_normalized', 'happy_normalized', 'sorrow_normalized', 'Week_dt', 'Week_dt_next', 'YearID_next', 'languages'], inplace = True)
# Check that these columns are removed.
df.dtypes
# Out:
# WeekID                          object
# Week Position                    int64
# Song                            object
# SongID                          object
# Instance                         int64
# Previous Week Position         float64
# Peak Position                    int64
# Weeks on Chart                   int64
# Artist                          object
# wordCount                      float64
# allWordCount                   float64
# year                           float64
# MTLD                           float64
# TTR                            float64
# CTTR                           float64
# sentimentScore                 float64
# sentimentScore_pos             float64
# sentimentScore_neg             float64
# emoWordCount                   float64
# emo_score                      float64
# YearID                           int64
# DecadeID                        object
# SuccessInd                       int64
# PrimaryKey                      object
# Artist_Count_Total             float64
# Artist_Count_Year              float64
# Artist_Count_Year_prior        float64
# Artist_Count_Week              float64
# Artist_Count_Week_prior        float64
# joy_normalized_ind               int64
# sadness_normalized_ind           int64
# anger_normalized_ind             int64
# disgust_normalized_ind           int64
# trust_normalized_ind             int64
# anticipation_normalized_ind      int64
# fear_normalized_ind              int64
# surprise_normalized_ind          int64
# happy_normalized_ind             int64
# sorrow_normalized_ind            int64
# 00s                              uint8
# 10s                              uint8
# 20s                              uint8
# 50s                              uint8
# 60s                              uint8
# 70s                              uint8
# 80s                              uint8
# 90s                              uint8
# dtype: object

# %% [markdown]
# ## 1. Train-Test Split

# %%
# Create a Train and Test dataset. 70% will be used for training.
## Week position will be our observed column.
len(df) * .7, len(df) * .3

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='Week Position'), 
                                                    df['Week Position'], test_size=0.3, 
                                                    random_state=123)

# %%
# Check our training set.
X_train.shape, X_test.shape
# Out:
# ((229526, 46), (98369, 46))

# %%
# Check our test set.
y_train.shape, y_test.shape
# Out:
# ((229526,), (98369,))

# %%
# Do the ratios of 'Week Position' match across Train and Test sets?
print(y_train.sum()/(len(X_train) + len(y_train)))
print(y_test.sum()/(len(X_test) + len(y_test)))
# Out:
# 25.216724902625412
# 25.326490052760523

# %% [markdown]
# ## 2. Remove PrimaryKey columns from Train & Test data

# %%
#Save the 'Week Position', 'Song', 'SongID', 'Artist', 'languages', 'year', 'PrimaryKey', 'DecadeID' columns from the train/test data into names_train and names_test
#Then drop those columns from `X_train` and `X_test`. Use 'inplace=True'
names_list = ['SuccessInd', 'Song', 'SongID', 'Artist', 'year', 'PrimaryKey', 'WeekID', 'DecadeID', 'YearID']
names_train = X_train[names_list]
names_test = X_test[names_list]
X_train.drop(columns=names_list, inplace=True)
X_test.drop(columns=names_list, inplace=True)
X_train.shape, X_test.shape
# Out:
# ((229526, 37), (98369, 37))

# %% [markdown]
# ## 3. Utilize pycaret

# %% [markdown]
# Pycaret is an open source library for automating machine learning work flows. We use the functionality below to test for the optimal machine learning algorithm in our dataset.
# For more information: https://pycaret.gitbook.io/docs/get-started/tutorials

# %%
# Create dataset for pycaret analysis. We will use our entire dataset for this analysis.
df_2 = df.drop(columns = names_list)

# %%
# Set up the dataset.
grid = setup(data = df_2, target = 'Week Position')
# Out:
# <style type="text/css">
# #T_5d9b1_row3_col1, #T_5d9b1_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5d9b1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d9b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d9b1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_5d9b1_row0_col1" class="data row0 col1" >3988</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d9b1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5d9b1_row1_col1" class="data row1 col1" >Week Position</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d9b1_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_5d9b1_row2_col1" class="data row2 col1" >(327895, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d9b1_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_5d9b1_row3_col1" class="data row3 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d9b1_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_5d9b1_row4_col1" class="data row4 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d9b1_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_5d9b1_row5_col1" class="data row5 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5d9b1_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_5d9b1_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5d9b1_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_5d9b1_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5d9b1_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_5d9b1_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5d9b1_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_5d9b1_row9_col1" class="data row9 col1" >(229526, 86)</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5d9b1_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_5d9b1_row10_col1" class="data row10 col1" >(98369, 86)</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5d9b1_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_5d9b1_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5d9b1_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_5d9b1_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5d9b1_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_5d9b1_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5d9b1_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_5d9b1_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5d9b1_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_5d9b1_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5d9b1_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_5d9b1_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5d9b1_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_5d9b1_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5d9b1_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_5d9b1_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5d9b1_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_5d9b1_row19_col1" class="data row19 col1" >29a2</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5d9b1_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_5d9b1_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5d9b1_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_5d9b1_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5d9b1_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_5d9b1_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5d9b1_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_5d9b1_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5d9b1_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_5d9b1_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5d9b1_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_5d9b1_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5d9b1_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_5d9b1_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5d9b1_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_5d9b1_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5d9b1_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_5d9b1_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_5d9b1_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_5d9b1_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d9b1_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_5d9b1_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_5d9b1_row30_col1" class="data row30 col1

# %%
# Evaluate and compare models
best = compare_models(fold = 5, n_select = 5)
# Out:
# <style type="text/css">
# #T_728c2_ th {
#   text-align: left;
# }
# #T_728c2_row0_col0, #T_728c2_row0_col1, #T_728c2_row0_col5, #T_728c2_row0_col6, #T_728c2_row1_col0, #T_728c2_row1_col2, #T_728c2_row1_col3, #T_728c2_row1_col4, #T_728c2_row2_col0, #T_728c2_row2_col1, #T_728c2_row2_col2, #T_728c2_row2_col3, #T_728c2_row2_col4, #T_728c2_row2_col5, #T_728c2_row2_col6, #T_728c2_row3_col0, #T_728c2_row3_col1, #T_728c2_row3_col2, #T_728c2_row3_col3, #T_728c2_row3_col4, #T_728c2_row3_col5, #T_728c2_row3_col6, #T_728c2_row4_col0, #T_728c2_row4_col1, #T_728c2_row4_col2, #T_728c2_row4_col3, #T_728c2_row4_col4, #T_728c2_row4_col5, #T_728c2_row4_col6, #T_728c2_row5_col0, #T_728c2_row5_col1, #T_728c2_row5_col2, #T_728c2_row5_col3, #T_728c2_row5_col4, #T_728c2_row5_col5, #T_728c2_row5_col6, #T_728c2_row6_col0, #T_728c2_row6_col1, #T_728c2_row6_col2, #T_728c2_row6_col3, #T_728c2_row6_col4, #T_728c2_row6_col5, #T_728c2_row6_col6, #T_728c2_row7_col0, #T_728c2_row7_col1, #T_728c2_row7_col2, #T_728c2_row7_col3, #T_728c2_row7_col4, #T_728c2_row7_col5, #T_728c2_row7_col6, #T_728c2_row8_col0, #T_728c2_row8_col1, #T_728c2_row8_col2, #T_728c2_row8_col3, #T_728c2_row8_col4, #T_728c2_row8_col5, #T_728c2_row8_col6, #T_728c2_row9_col0, #T_728c2_row9_col1, #T_728c2_row9_col2, #T_728c2_row9_col3, #T_728c2_row9_col4, #T_728c2_row9_col5, #T_728c2_row9_col6, #T_728c2_row10_col0, #T_728c2_row10_col1, #T_728c2_row10_col2, #T_728c2_row10_col3, #T_728c2_row10_col4, #T_728c2_row10_col5, #T_728c2_row10_col6, #T_728c2_row11_col0, #T_728c2_row11_col1, #T_728c2_row11_col2, #T_728c2_row11_col3, #T_728c2_row11_col4, #T_728c2_row11_col5, #T_728c2_row11_col6, #T_728c2_row12_col0, #T_728c2_row12_col1, #T_728c2_row12_col2, #T_728c2_row12_col3, #T_728c2_row12_col4, #T_728c2_row12_col5, #T_728c2_row12_col6, #T_728c2_row13_col0, #T_728c2_row13_col1, #T_728c2_row13_col2, #T_728c2_row13_col3, #T_728c2_row13_col4, #T_728c2_row13_col5, #T_728c2_row13_col6, #T_728c2_row14_col0, #T_728c2_row14_col1, #T_728c2_row14_col2, #T_728c2_row14_col3, #T_728c2_row14_col4, #T_728c2_row14_col5, #T_728c2_row14_col6, #T_728c2_row15_col0, #T_728c2_row15_col1, #T_728c2_row15_col2, #T_728c2_row15_col3, #T_728c2_row15_col4, #T_728c2_row15_col5, #T_728c2_row15_col6, #T_728c2_row16_col0, #T_728c2_row16_col1, #T_728c2_row16_col2, #T_728c2_row16_col3, #T_728c2_row16_col4, #T_728c2_row16_col5, #T_728c2_row16_col6, #T_728c2_row17_col0, #T_728c2_row17_col1, #T_728c2_row17_col2, #T_728c2_row17_col3, #T_728c2_row17_col4, #T_728c2_row17_col5, #T_728c2_row17_col6 {
#   text-align: left;
# }
# #T_728c2_row0_col2, #T_728c2_row0_col3, #T_728c2_row0_col4, #T_728c2_row1_col1, #T_728c2_row1_col5, #T_728c2_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_728c2_row0_col7, #T_728c2_row1_col7, #T_728c2_row2_col7, #T_728c2_row3_col7, #T_728c2_row4_col7, #T_728c2_row5_col7, #T_728c2_row6_col7, #T_728c2_row7_col7, #T_728c2_row8_col7, #T_728c2_row9_col7, #T_728c2_row10_col7, #T_728c2_row11_col7, #T_728c2_row12_col7, #T_728c2_row13_col7, #T_728c2_row14_col7, #T_728c2_row16_col7, #T_728c2_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_728c2_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_728c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_728c2_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_728c2_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_728c2_row0_col1" class="data row0 col1" >3.4965</td>
#       <td id="T_728c2_row0_col2" class="data row0 col2" >36.9743</td>
#       <td id="T_728c2_row0_col3" class="data row0 col3" >6.0806</td>
#       <td id="T_728c2_row0_col4" class="data row0 col4" >0.9556</td>
#       <td id="T_728c2_row0_col5" class="data row0 col5" >0.1900</td>
#       <td id="T_728c2_row0_col6" class="data row0 col6" >0.1341</td>
#       <td id="T_728c2_row0_col7" class="data row0 col7" >5.2800</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_728c2_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_728c2_row1_col1" class="data row1 col1" >3.3383</td>
#       <td id="T_728c2_row1_col2" class="data row1 col2" >37.5665</td>
#       <td id="T_728c2_row1_col3" class="data row1 col3" >6.1290</td>
#       <td id="T_728c2_row1_col4" class="data row1 col4" >0.9549</td>
#       <td id="T_728c2_row1_col5" class="data row1 col5" >0.1849</td>
#       <td id="T_728c2_row1_col6" class="data row1 col6" >0.1209</td>
#       <td id="T_728c2_row1_col7" class="data row1 col7" >255.5020</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_728c2_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_728c2_row2_col1" class="data row2 col1" >3.3555</td>
#       <td id="T_728c2_row2_col2" class="data row2 col2" >37.8741</td>
#       <td id="T_728c2_row2_col3" class="data row2 col3" >6.1541</td>
#       <td id="T_728c2_row2_col4" class="data row2 col4" >0.9545</td>
#       <td id="T_728c2_row2_col5" class="data row2 col5" >0.1878</td>
#       <td id="T_728c2_row2_col6" class="data row2 col6" >0.1232</td>
#       <td id="T_728c2_row2_col7" class="data row2 col7" >292.0580</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_728c2_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_728c2_row3_col1" class="data row3 col1" >4.4436</td>
#       <td id="T_728c2_row3_col2" class="data row3 col2" >51.7918</td>
#       <td id="T_728c2_row3_col3" class="data row3 col3" >7.1965</td>
#       <td id="T_728c2_row3_col4" class="data row3 col4" >0.9378</td>
#       <td id="T_728c2_row3_col5" class="data row3 col5" >0.2295</td>
#       <td id="T_728c2_row3_col6" class="data row3 col6" >0.1811</td>
#       <td id="T_728c2_row3_col7" class="data row3 col7" >88.3660</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_728c2_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_728c2_row4_col1" class="data row4 col1" >4.2486</td>
#       <td id="T_728c2_row4_col2" class="data row4 col2" >72.9050</td>
#       <td id="T_728c2_row4_col3" class="data row4 col3" >8.5384</td>
#       <td id="T_728c2_row4_col4" class="data row4 col4" >0.9125</td>
#       <td id="T_728c2_row4_col5" class="data row4 col5" >0.2475</td>
#       <td id="T_728c2_row4_col6" class="data row4 col6" >0.1464</td>
#       <td id="T_728c2_row4_col7" class="data row4 col7" >16.4720</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_728c2_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_728c2_row5_col1" class="data row5 col1" >6.6152</td>
#       <td id="T_728c2_row5_col2" class="data row5 col2" >103.5933</td>
#       <td id="T_728c2_row5_col3" class="data row5 col3" >10.1780</td>
#       <td id="T_728c2_row5_col4" class="data row5 col4" >0.8757</td>
#       <td id="T_728c2_row5_col5" class="data row5 col5" >0.3244</td>
#       <td id="T_728c2_row5_col6" class="data row5 col6" >0.2621</td>
#       <td id="T_728c2_row5_col7" class="data row5 col7" >30.0680</td>
#     </tr>
#     <tr>
#       <th id="T_728c2_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_728c2_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_728c2_row6_col1" class="data row6 co

# %% [markdown]
# The top 5 models based on MSE, RMSE, and R2 are Light Gradient Boosting Machine, Random Forest Regressor, and Extra Trees Regressor, Gradient Boosting Regressor, and Gradient Boosting Regressor.

# %% [markdown]
# ## 4. Test Top Algorithms

# %% [markdown]
# We will test the top performing algorithms to check metrics on 10-fold and analyze whether or not they perform consistently.

# %% [markdown]
# ### 4a. Light Gradient Boosting Machine

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_8fa02_row10_col0, #T_8fa02_row10_col1, #T_8fa02_row10_col2, #T_8fa02_row10_col3, #T_8fa02_row10_col4, #T_8fa02_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8fa02_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fa02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fa02_row0_col0" class="data row0 col0" >3.4968</td>
#       <td id="T_8fa02_row0_col1" class="data row0 col1" >36.8360</td>
#       <td id="T_8fa02_row0_col2" class="data row0 col2" >6.0693</td>
#       <td id="T_8fa02_row0_col3" class="data row0 col3" >0.9556</td>
#       <td id="T_8fa02_row0_col4" class="data row0 col4" >0.1913</td>
#       <td id="T_8fa02_row0_col5" class="data row0 col5" >0.1344</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fa02_row1_col0" class="data row1 col0" >3.4520</td>
#       <td id="T_8fa02_row1_col1" class="data row1 col1" >35.8612</td>
#       <td id="T_8fa02_row1_col2" class="data row1 col2" >5.9884</td>
#       <td id="T_8fa02_row1_col3" class="data row1 col3" >0.9573</td>
#       <td id="T_8fa02_row1_col4" class="data row1 col4" >0.1861</td>
#       <td id="T_8fa02_row1_col5" class="data row1 col5" >0.1324</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8fa02_row2_col0" class="data row2 col0" >3.4777</td>
#       <td id="T_8fa02_row2_col1" class="data row2 col1" >37.5800</td>
#       <td id="T_8fa02_row2_col2" class="data row2 col2" >6.1303</td>
#       <td id="T_8fa02_row2_col3" class="data row2 col3" >0.9548</td>
#       <td id="T_8fa02_row2_col4" class="data row2 col4" >0.1874</td>
#       <td id="T_8fa02_row2_col5" class="data row2 col5" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8fa02_row3_col0" class="data row3 col0" >3.4990</td>
#       <td id="T_8fa02_row3_col1" class="data row3 col1" >37.3604</td>
#       <td id="T_8fa02_row3_col2" class="data row3 col2" >6.1123</td>
#       <td id="T_8fa02_row3_col3" class="data row3 col3" >0.9555</td>
#       <td id="T_8fa02_row3_col4" class="data row3 col4" >0.1926</td>
#       <td id="T_8fa02_row3_col5" class="data row3 col5" >0.1376</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8fa02_row4_col0" class="data row4 col0" >3.4716</td>
#       <td id="T_8fa02_row4_col1" class="data row4 col1" >36.0861</td>
#       <td id="T_8fa02_row4_col2" class="data row4 col2" >6.0072</td>
#       <td id="T_8fa02_row4_col3" class="data row4 col3" >0.9564</td>
#       <td id="T_8fa02_row4_col4" class="data row4 col4" >0.1860</td>
#       <td id="T_8fa02_row4_col5" class="data row4 col5" >0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8fa02_row5_col0" class="data row5 col0" >3.5065</td>
#       <td id="T_8fa02_row5_col1" class="data row5 col1" >36.6258</td>
#       <td id="T_8fa02_row5_col2" class="data row5 col2" >6.0519</td>
#       <td id="T_8fa02_row5_col3" class="data row5 col3" >0.9562</td>
#       <td id="T_8fa02_row5_col4" class="data row5 col4" >0.1902</td>
#       <td id="T_8fa02_row5_col5" class="data row5 col5" >0.1352</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8fa02_row6_col0" class="data row6 col0" >3.4924</td>
#       <td id="T_8fa02_row6_col1" class="data row6 col1" >36.0995</td>
#       <td id="T_8fa02_row6_col2" class="data row6 col2" >6.0083</td>
#       <td id="T_8fa02_row6_col3" class="data row6 col3" >0.9567</td>
#       <td id="T_8fa02_row6_col4" class="data row6 col4" >0.1917</td>
#       <td id="T_8fa02_row6_col5" class="data row6 col5" >0.1373</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8fa02_row7_col0" class="data row7 col0" >3.5279</td>
#       <td id="T_8fa02_row7_col1" class="data row7 col1" >38.0255</td>
#       <td id="T_8fa02_row7_col2" class="data row7 col2" >6.1665</td>
#       <td id="T_8fa02_row7_col3" class="data row7 col3" >0.9540</td>
#       <td id="T_8fa02_row7_col4" class="data row7 col4" >0.1881</td>
#       <td id="T_8fa02_row7_col5" class="data row7 col5" >0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8fa02_row8_col0" class="data row8 col0" >3.4631</td>
#       <td id="T_8fa02_row8_col1" class="data row8 col1" >35.6550</td>
#       <td id="T_8fa02_row8_col2" class="data row8 col2" >5.9712</td>
#       <td id="T_8fa02_row8_col3" class="data row8 col3" >0.9572</td>
#       <td id="T_8fa02_row8_col4" class="data row8 col4" >0.1910</td>
#       <td id="T_8fa02_row8_col5" class="data row8 col5" >0.1341</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8fa02_row9_col0" class="data row9 col0" >3.5611</td>
#       <td id="T_8fa02_row9_col1" class="data row9 col1" >38.2457</td>
#       <td id="T_8fa02_row9_col2" class="data row9 col2" >6.1843</td>
#       <td id="T_8fa02_row9_col3" class="data row9 col3" >0.9542</td>
#       <td id="T_8fa02_row9_col4" class="data row9 col4" >0.1946</td>
#       <td id="T_8fa02_row9_col5" class="data row9 col5" >0.1377</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8fa02_row10_col0" class="data row10 col0" >3.4948</td>
#       <td id="T_8fa02_row10_col1" class="data row10 col1" >36.8375</td>
#       <td id="T_8fa02_row10_col2" class="data row10 col2" >6.0690</td>
#       <td id="T_8fa02_row10_col3" class="data row10 col3" >0.9558</td>
#       <td id="T_8fa02_row10_col4" class="data row10 col4" >0.1899</td>
#       <td id="T_8fa02_row10_col5" class="data row10 col5" >0.1341</td>
#     </tr>
#     <tr>
#       <th id="T_8fa02_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8fa02_row11_col0" class="data row11 col0" >0.0305</td>
#       <td id="T_8fa02_row11_col1" class="data row11 col1" >0.8789</td>
#       <td id="T_8fa02_row11_col2" class="data row11 col2" >0.0723</td>
#       <td id="T_8fa02_row11_col3" class="data row11 col3" >0.0011</td>
#       <td id="T_8fa02_row11_col4" class="data row11 col4" >0.0027</td>
#       <td id="T_8fa02_row11_col5" class="data row11 col5" >0.0027</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4b. Random Forest

# %%
rf = create_model("rf")
# Out:
# <style type="text/css">
# #T_f879d_row10_col0, #T_f879d_row10_col1, #T_f879d_row10_col2, #T_f879d_row10_col3, #T_f879d_row10_col4, #T_f879d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f879d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f879d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f879d_row0_col0" class="data row0 col0" >3.3440</td>
#       <td id="T_f879d_row0_col1" class="data row0 col1" >37.6142</td>
#       <td id="T_f879d_row0_col2" class="data row0 col2" >6.1330</td>
#       <td id="T_f879d_row0_col3" class="data row0 col3" >0.9547</td>
#       <td id="T_f879d_row0_col4" class="data row0 col4" >0.1871</td>
#       <td id="T_f879d_row0_col5" class="data row0 col5" >0.1216</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f879d_row1_col0" class="data row1 col0" >3.2659</td>
#       <td id="T_f879d_row1_col1" class="data row1 col1" >36.2393</td>
#       <td id="T_f879d_row1_col2" class="data row1 col2" >6.0199</td>
#       <td id="T_f879d_row1_col3" class="data row1 col3" >0.9568</td>
#       <td id="T_f879d_row1_col4" class="data row1 col4" >0.1805</td>
#       <td id="T_f879d_row1_col5" class="data row1 col5" >0.1182</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f879d_row2_col0" class="data row2 col0" >3.2959</td>
#       <td id="T_f879d_row2_col1" class="data row2 col1" >38.0855</td>
#       <td id="T_f879d_row2_col2" class="data row2 col2" >6.1713</td>
#       <td id="T_f879d_row2_col3" class="data row2 col3" >0.9541</td>
#       <td id="T_f879d_row2_col4" class="data row2 col4" >0.1828</td>
#       <td id="T_f879d_row2_col5" class="data row2 col5" >0.1174</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f879d_row3_col0" class="data row3 col0" >3.3439</td>
#       <td id="T_f879d_row3_col1" class="data row3 col1" >37.8853</td>
#       <td id="T_f879d_row3_col2" class="data row3 col2" >6.1551</td>
#       <td id="T_f879d_row3_col3" class="data row3 col3" >0.9549</td>
#       <td id="T_f879d_row3_col4" class="data row3 col4" >0.1873</td>
#       <td id="T_f879d_row3_col5" class="data row3 col5" >0.1234</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f879d_row4_col0" class="data row4 col0" >3.3307</td>
#       <td id="T_f879d_row4_col1" class="data row4 col1" >37.2858</td>
#       <td id="T_f879d_row4_col2" class="data row4 col2" >6.1062</td>
#       <td id="T_f879d_row4_col3" class="data row4 col3" >0.9549</td>
#       <td id="T_f879d_row4_col4" class="data row4 col4" >0.1819</td>
#       <td id="T_f879d_row4_col5" class="data row4 col5" >0.1192</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f879d_row5_col0" class="data row5 col0" >3.3306</td>
#       <td id="T_f879d_row5_col1" class="data row5 col1" >36.6825</td>
#       <td id="T_f879d_row5_col2" class="data row5 col2" >6.0566</td>
#       <td id="T_f879d_row5_col3" class="data row5 col3" >0.9562</td>
#       <td id="T_f879d_row5_col4" class="data row5 col4" >0.1852</td>
#       <td id="T_f879d_row5_col5" class="data row5 col5" >0.1219</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f879d_row6_col0" class="data row6 col0" >3.3013</td>
#       <td id="T_f879d_row6_col1" class="data row6 col1" >36.5180</td>
#       <td id="T_f879d_row6_col2" class="data row6 col2" >6.0430</td>
#       <td id="T_f879d_row6_col3" class="data row6 col3" >0.9562</td>
#       <td id="T_f879d_row6_col4" class="data row6 col4" >0.1837</td>
#       <td id="T_f879d_row6_col5" class="data row6 col5" >0.1198</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f879d_row7_col0" class="data row7 col0" >3.3459</td>
#       <td id="T_f879d_row7_col1" class="data row7 col1" >38.3249</td>
#       <td id="T_f879d_row7_col2" class="data row7 col2" >6.1907</td>
#       <td id="T_f879d_row7_col3" class="data row7 col3" >0.9536</td>
#       <td id="T_f879d_row7_col4" class="data row7 col4" >0.1808</td>
#       <td id="T_f879d_row7_col5" class="data row7 col5" >0.1166</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f879d_row8_col0" class="data row8 col0" >3.2968</td>
#       <td id="T_f879d_row8_col1" class="data row8 col1" >36.5501</td>
#       <td id="T_f879d_row8_col2" class="data row8 col2" >6.0457</td>
#       <td id="T_f879d_row8_col3" class="data row8 col3" >0.9562</td>
#       <td id="T_f879d_row8_col4" class="data row8 col4" >0.1851</td>
#       <td id="T_f879d_row8_col5" class="data row8 col5" >0.1196</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f879d_row9_col0" class="data row9 col0" >3.3935</td>
#       <td id="T_f879d_row9_col1" class="data row9 col1" >39.2730</td>
#       <td id="T_f879d_row9_col2" class="data row9 col2" >6.2668</td>
#       <td id="T_f879d_row9_col3" class="data row9 col3" >0.9529</td>
#       <td id="T_f879d_row9_col4" class="data row9 col4" >0.1892</td>
#       <td id="T_f879d_row9_col5" class="data row9 col5" >0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f879d_row10_col0" class="data row10 col0" >3.3249</td>
#       <td id="T_f879d_row10_col1" class="data row10 col1" >37.4459</td>
#       <td id="T_f879d_row10_col2" class="data row10 col2" >6.1188</td>
#       <td id="T_f879d_row10_col3" class="data row10 col3" >0.9551</td>
#       <td id="T_f879d_row10_col4" class="data row10 col4" >0.1843</td>
#       <td id="T_f879d_row10_col5" class="data row10 col5" >0.1201</td>
#     </tr>
#     <tr>
#       <th id="T_f879d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f879d_row11_col0" class="data row11 col0" >0.0341</td>
#       <td id="T_f879d_row11_col1" class="data row11 col1" >0.9203</td>
#       <td id="T_f879d_row11_col2" class="data row11 col2" >0.0750</td>
#       <td id="T_f879d_row11_col3" class="data row11 col3" >0.0012</td>
#       <td id="T_f879d_row11_col4" class="data row11 col4" >0.0028</td>
#       <td id="T_f879d_row11_col5" class="data row11 col5" >0.0022</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4c. Gradient Boosting Regressor

# %%
gb = create_model("gbr")
# Out:
# <style type="text/css">
# #T_d3fb3_row10_col0, #T_d3fb3_row10_col1, #T_d3fb3_row10_col2, #T_d3fb3_row10_col3, #T_d3fb3_row10_col4, #T_d3fb3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d3fb3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3fb3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3fb3_row0_col0" class="data row0 col0" >4.4222</td>
#       <td id="T_d3fb3_row0_col1" class="data row0 col1" >50.7048</td>
#       <td id="T_d3fb3_row0_col2" class="data row0 col2" >7.1207</td>
#       <td id="T_d3fb3_row0_col3" class="data row0 col3" >0.9389</td>
#       <td id="T_d3fb3_row0_col4" class="data row0 col4" >0.2289</td>
#       <td id="T_d3fb3_row0_col5" class="data row0 col5" >0.1805</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3fb3_row1_col0" class="data row1 col0" >4.4204</td>
#       <td id="T_d3fb3_row1_col1" class="data row1 col1" >51.7984</td>
#       <td id="T_d3fb3_row1_col2" class="data row1 col2" >7.1971</td>
#       <td id="T_d3fb3_row1_col3" class="data row1 col3" >0.9383</td>
#       <td id="T_d3fb3_row1_col4" class="data row1 col4" >0.2301</td>
#       <td id="T_d3fb3_row1_col5" class="data row1 col5" >0.1836</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3fb3_row2_col0" class="data row2 col0" >4.3743</td>
#       <td id="T_d3fb3_row2_col1" class="data row2 col1" >51.2136</td>
#       <td id="T_d3fb3_row2_col2" class="data row2 col2" >7.1564</td>
#       <td id="T_d3fb3_row2_col3" class="data row2 col3" >0.9383</td>
#       <td id="T_d3fb3_row2_col4" class="data row2 col4" >0.2251</td>
#       <td id="T_d3fb3_row2_col5" class="data row2 col5" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3fb3_row3_col0" class="data row3 col0" >4.4135</td>
#       <td id="T_d3fb3_row3_col1" class="data row3 col1" >52.0890</td>
#       <td id="T_d3fb3_row3_col2" class="data row3 col2" >7.2173</td>
#       <td id="T_d3fb3_row3_col3" class="data row3 col3" >0.9380</td>
#       <td id="T_d3fb3_row3_col4" class="data row3 col4" >0.2319</td>
#       <td id="T_d3fb3_row3_col5" class="data row3 col5" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3fb3_row4_col0" class="data row4 col0" >4.4383</td>
#       <td id="T_d3fb3_row4_col1" class="data row4 col1" >51.3881</td>
#       <td id="T_d3fb3_row4_col2" class="data row4 col2" >7.1685</td>
#       <td id="T_d3fb3_row4_col3" class="data row4 col3" >0.9379</td>
#       <td id="T_d3fb3_row4_col4" class="data row4 col4" >0.2263</td>
#       <td id="T_d3fb3_row4_col5" class="data row4 col5" >0.1799</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3fb3_row5_col0" class="data row5 col0" >4.4546</td>
#       <td id="T_d3fb3_row5_col1" class="data row5 col1" >52.0937</td>
#       <td id="T_d3fb3_row5_col2" class="data row5 col2" >7.2176</td>
#       <td id="T_d3fb3_row5_col3" class="data row5 col3" >0.9378</td>
#       <td id="T_d3fb3_row5_col4" class="data row5 col4" >0.2307</td>
#       <td id="T_d3fb3_row5_col5" class="data row5 col5" >0.1827</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3fb3_row6_col0" class="data row6 col0" >4.4637</td>
#       <td id="T_d3fb3_row6_col1" class="data row6 col1" >51.7388</td>
#       <td id="T_d3fb3_row6_col2" class="data row6 col2" >7.1930</td>
#       <td id="T_d3fb3_row6_col3" class="data row6 col3" >0.9379</td>
#       <td id="T_d3fb3_row6_col4" class="data row6 col4" >0.2325</td>
#       <td id="T_d3fb3_row6_col5" class="data row6 col5" >0.1842</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d3fb3_row7_col0" class="data row7 col0" >4.4064</td>
#       <td id="T_d3fb3_row7_col1" class="data row7 col1" >50.9597</td>
#       <td id="T_d3fb3_row7_col2" class="data row7 col2" >7.1386</td>
#       <td id="T_d3fb3_row7_col3" class="data row7 col3" >0.9383</td>
#       <td id="T_d3fb3_row7_col4" class="data row7 col4" >0.2231</td>
#       <td id="T_d3fb3_row7_col5" class="data row7 col5" >0.1742</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d3fb3_row8_col0" class="data row8 col0" >4.4171</td>
#       <td id="T_d3fb3_row8_col1" class="data row8 col1" >50.9590</td>
#       <td id="T_d3fb3_row8_col2" class="data row8 col2" >7.1386</td>
#       <td id="T_d3fb3_row8_col3" class="data row8 col3" >0.9389</td>
#       <td id="T_d3fb3_row8_col4" class="data row8 col4" >0.2299</td>
#       <td id="T_d3fb3_row8_col5" class="data row8 col5" >0.1804</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d3fb3_row9_col0" class="data row9 col0" >4.5057</td>
#       <td id="T_d3fb3_row9_col1" class="data row9 col1" >52.7087</td>
#       <td id="T_d3fb3_row9_col2" class="data row9 col2" >7.2601</td>
#       <td id="T_d3fb3_row9_col3" class="data row9 col3" >0.9368</td>
#       <td id="T_d3fb3_row9_col4" class="data row9 col4" >0.2318</td>
#       <td id="T_d3fb3_row9_col5" class="data row9 col5" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d3fb3_row10_col0" class="data row10 col0" >4.4316</td>
#       <td id="T_d3fb3_row10_col1" class="data row10 col1" >51.5654</td>
#       <td id="T_d3fb3_row10_col2" class="data row10 col2" >7.1808</td>
#       <td id="T_d3fb3_row10_col3" class="data row10 col3" >0.9381</td>
#       <td id="T_d3fb3_row10_col4" class="data row10 col4" >0.2290</td>
#       <td id="T_d3fb3_row10_col5" class="data row10 col5" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_d3fb3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d3fb3_row11_col0" class="data row11 col0" >0.0343</td>
#       <td id="T_d3fb3_row11_col1" class="data row11 col1" >0.5979</td>
#       <td id="T_d3fb3_row11_col2" class="data row11 col2" >0.0416</td>
#       <td id="T_d3fb3_row11_col3" class="data row11 col3" >0.0006</td>
#       <td id="T_d3fb3_row11_col4" class="data row11 col4" >0.0030</td>
#       <td id="T_d3fb3_row11_col5" class="data row11 col5" >0.0040</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4d. K-nearest neighbors

# %%
knn = create_model("knn")
# Out:
# <style type="text/css">
# #T_b644c_row10_col0, #T_b644c_row10_col1, #T_b644c_row10_col2, #T_b644c_row10_col3, #T_b644c_row10_col4, #T_b644c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b644c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b644c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b644c_row0_col0" class="data row0 col0" >6.3927</td>
#       <td id="T_b644c_row0_col1" class="data row0 col1" >97.5684</td>
#       <td id="T_b644c_row0_col2" class="data row0 col2" >9.8777</td>
#       <td id="T_b644c_row0_col3" class="data row0 col3" >0.8825</td>
#       <td id="T_b644c_row0_col4" class="data row0 col4" >0.3106</td>
#       <td id="T_b644c_row0_col5" class="data row0 col5" >0.2448</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b644c_row1_col0" class="data row1 col0" >6.4692</td>
#       <td id="T_b644c_row1_col1" class="data row1 col1" >100.9115</td>
#       <td id="T_b644c_row1_col2" class="data row1 col2" >10.0455</td>
#       <td id="T_b644c_row1_col3" class="data row1 col3" >0.8797</td>
#       <td id="T_b644c_row1_col4" class="data row1 col4" >0.3149</td>
#       <td id="T_b644c_row1_col5" class="data row1 col5" >0.2509</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b644c_row2_col0" class="data row2 col0" >6.4972</td>
#       <td id="T_b644c_row2_col1" class="data row2 col1" >102.1397</td>
#       <td id="T_b644c_row2_col2" class="data row2 col2" >10.1064</td>
#       <td id="T_b644c_row2_col3" class="data row2 col3" >0.8770</td>
#       <td id="T_b644c_row2_col4" class="data row2 col4" >0.3161</td>
#       <td id="T_b644c_row2_col5" class="data row2 col5" >0.2443</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b644c_row3_col0" class="data row3 col0" >6.4780</td>
#       <td id="T_b644c_row3_col1" class="data row3 col1" >101.6405</td>
#       <td id="T_b644c_row3_col2" class="data row3 col2" >10.0817</td>
#       <td id="T_b644c_row3_col3" class="data row3 col3" >0.8790</td>
#       <td id="T_b644c_row3_col4" class="data row3 col4" >0.3138</td>
#       <td id="T_b644c_row3_col5" class="data row3 col5" >0.2510</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b644c_row4_col0" class="data row4 col0" >6.4232</td>
#       <td id="T_b644c_row4_col1" class="data row4 col1" >99.9467</td>
#       <td id="T_b644c_row4_col2" class="data row4 col2" >9.9973</td>
#       <td id="T_b644c_row4_col3" class="data row4 col3" >0.8791</td>
#       <td id="T_b644c_row4_col4" class="data row4 col4" >0.3092</td>
#       <td id="T_b644c_row4_col5" class="data row4 col5" >0.2389</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b644c_row5_col0" class="data row5 col0" >6.4732</td>
#       <td id="T_b644c_row5_col1" class="data row5 col1" >100.8688</td>
#       <td id="T_b644c_row5_col2" class="data row5 col2" >10.0433</td>
#       <td id="T_b644c_row5_col3" class="data row5 col3" >0.8795</td>
#       <td id="T_b644c_row5_col4" class="data row5 col4" >0.3141</td>
#       <td id="T_b644c_row5_col5" class="data row5 col5" >0.2500</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b644c_row6_col0" class="data row6 col0" >6.4655</td>
#       <td id="T_b644c_row6_col1" class="data row6 col1" >99.9776</td>
#       <td id="T_b644c_row6_col2" class="data row6 col2" >9.9989</td>
#       <td id="T_b644c_row6_col3" class="data row6 col3" >0.8800</td>
#       <td id="T_b644c_row6_col4" class="data row6 col4" >0.3176</td>
#       <td id="T_b644c_row6_col5" class="data row6 col5" >0.2541</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b644c_row7_col0" class="data row7 col0" >6.4553</td>
#       <td id="T_b644c_row7_col1" class="data row7 col1" >99.3806</td>
#       <td id="T_b644c_row7_col2" class="data row7 col2" >9.9690</td>
#       <td id="T_b644c_row7_col3" class="data row7 col3" >0.8798</td>
#       <td id="T_b644c_row7_col4" class="data row7 col4" >0.3091</td>
#       <td id="T_b644c_row7_col5" class="data row7 col5" >0.2420</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b644c_row8_col0" class="data row8 col0" >6.5002</td>
#       <td id="T_b644c_row8_col1" class="data row8 col1" >102.2723</td>
#       <td id="T_b644c_row8_col2" class="data row8 col2" >10.1130</td>
#       <td id="T_b644c_row8_col3" class="data row8 col3" >0.8774</td>
#       <td id="T_b644c_row8_col4" class="data row8 col4" >0.3221</td>
#       <td id="T_b644c_row8_col5" class="data row8 col5" >0.2519</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b644c_row9_col0" class="data row9 col0" >6.4508</td>
#       <td id="T_b644c_row9_col1" class="data row9 col1" >99.4930</td>
#       <td id="T_b644c_row9_col2" class="data row9 col2" >9.9746</td>
#       <td id="T_b644c_row9_col3" class="data row9 col3" >0.8808</td>
#       <td id="T_b644c_row9_col4" class="data row9 col4" >0.3114</td>
#       <td id="T_b644c_row9_col5" class="data row9 col5" >0.2443</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b644c_row10_col0" class="data row10 col0" >6.4606</td>
#       <td id="T_b644c_row10_col1" class="data row10 col1" >100.4199</td>
#       <td id="T_b644c_row10_col2" class="data row10 col2" >10.0207</td>
#       <td id="T_b644c_row10_col3" class="data row10 col3" >0.8795</td>
#       <td id="T_b644c_row10_col4" class="data row10 col4" >0.3139</td>
#       <td id="T_b644c_row10_col5" class="data row10 col5" >0.2472</td>
#     </tr>
#     <tr>
#       <th id="T_b644c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b644c_row11_col0" class="data row11 col0" >0.0310</td>
#       <td id="T_b644c_row11_col1" class="data row11 col1" >1.3716</td>
#       <td id="T_b644c_row11_col2" class="data row11 col2" >0.0685</td>
#       <td id="T_b644c_row11_col3" class="data row11 col3" >0.0015</td>
#       <td id="T_b644c_row11_col4" class="data row11 col4" >0.0039</td>
#       <td id="T_b644c_row11_col5" class="data row11 col5" >0.0047</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4e. Ridge Regression

# %%
ridge = create_model("ridge")
# Out:
# <style type="text/css">
# #T_ed407_row10_col0, #T_ed407_row10_col1, #T_ed407_row10_col2, #T_ed407_row10_col3, #T_ed407_row10_col4, #T_ed407_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ed407_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed407_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed407_row0_col0" class="data row0 col0" >9.3252</td>
#       <td id="T_ed407_row0_col1" class="data row0 col1" >206.8801</td>
#       <td id="T_ed407_row0_col2" class="data row0 col2" >14.3833</td>
#       <td id="T_ed407_row0_col3" class="data row0 col3" >0.7508</td>
#       <td id="T_ed407_row0_col4" class="data row0 col4" >0.4813</td>
#       <td id="T_ed407_row0_col5" class="data row0 col5" >0.5271</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed407_row1_col0" class="data row1 col0" >9.2350</td>
#       <td id="T_ed407_row1_col1" class="data row1 col1" >201.4963</td>
#       <td id="T_ed407_row1_col2" class="data row1 col2" >14.1949</td>
#       <td id="T_ed407_row1_col3" class="data row1 col3" >0.7599</td>
#       <td id="T_ed407_row1_col4" class="data row1 col4" >0.4827</td>
#       <td id="T_ed407_row1_col5" class="data row1 col5" >0.5248</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed407_row2_col0" class="data row2 col0" >9.2324</td>
#       <td id="T_ed407_row2_col1" class="data row2 col1" >202.8831</td>
#       <td id="T_ed407_row2_col2" class="data row2 col2" >14.2437</td>
#       <td id="T_ed407_row2_col3" class="data row2 col3" >0.7557</td>
#       <td id="T_ed407_row2_col4" class="data row2 col4" >0.4741</td>
#       <td id="T_ed407_row2_col5" class="data row2 col5" >0.5096</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed407_row3_col0" class="data row3 col0" >9.2174</td>
#       <td id="T_ed407_row3_col1" class="data row3 col1" >199.8987</td>
#       <td id="T_ed407_row3_col2" class="data row3 col2" >14.1386</td>
#       <td id="T_ed407_row3_col3" class="data row3 col3" >0.7620</td>
#       <td id="T_ed407_row3_col4" class="data row3 col4" >0.4797</td>
#       <td id="T_ed407_row3_col5" class="data row3 col5" >0.5205</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed407_row4_col0" class="data row4 col0" >9.2063</td>
#       <td id="T_ed407_row4_col1" class="data row4 col1" >199.7813</td>
#       <td id="T_ed407_row4_col2" class="data row4 col2" >14.1344</td>
#       <td id="T_ed407_row4_col3" class="data row4 col3" >0.7584</td>
#       <td id="T_ed407_row4_col4" class="data row4 col4" >0.4690</td>
#       <td id="T_ed407_row4_col5" class="data row4 col5" >0.4978</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed407_row5_col0" class="data row5 col0" >9.3585</td>
#       <td id="T_ed407_row5_col1" class="data row5 col1" >208.4820</td>
#       <td id="T_ed407_row5_col2" class="data row5 col2" >14.4389</td>
#       <td id="T_ed407_row5_col3" class="data row5 col3" >0.7510</td>
#       <td id="T_ed407_row5_col4" class="data row5 col4" >0.4814</td>
#       <td id="T_ed407_row5_col5" class="data row5 col5" >0.5248</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed407_row6_col0" class="data row6 col0" >9.2516</td>
#       <td id="T_ed407_row6_col1" class="data row6 col1" >203.9646</td>
#       <td id="T_ed407_row6_col2" class="data row6 col2" >14.2816</td>
#       <td id="T_ed407_row6_col3" class="data row6 col3" >0.7553</td>
#       <td id="T_ed407_row6_col4" class="data row6 col4" >0.4885</td>
#       <td id="T_ed407_row6_col5" class="data row6 col5" >0.5392</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed407_row7_col0" class="data row7 col0" >9.2159</td>
#       <td id="T_ed407_row7_col1" class="data row7 col1" >202.3793</td>
#       <td id="T_ed407_row7_col2" class="data row7 col2" >14.2260</td>
#       <td id="T_ed407_row7_col3" class="data row7 col3" >0.7552</td>
#       <td id="T_ed407_row7_col4" class="data row7 col4" >0.4731</td>
#       <td id="T_ed407_row7_col5" class="data row7 col5" >0.5030</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed407_row8_col0" class="data row8 col0" >9.1908</td>
#       <td id="T_ed407_row8_col1" class="data row8 col1" >200.5581</td>
#       <td id="T_ed407_row8_col2" class="data row8 col2" >14.1619</td>
#       <td id="T_ed407_row8_col3" class="data row8 col3" >0.7595</td>
#       <td id="T_ed407_row8_col4" class="data row8 col4" >0.4745</td>
#       <td id="T_ed407_row8_col5" class="data row8 col5" >0.5075</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed407_row9_col0" class="data row9 col0" >9.2739</td>
#       <td id="T_ed407_row9_col1" class="data row9 col1" >202.3365</td>
#       <td id="T_ed407_row9_col2" class="data row9 col2" >14.2245</td>
#       <td id="T_ed407_row9_col3" class="data row9 col3" >0.7575</td>
#       <td id="T_ed407_row9_col4" class="data row9 col4" >0.4784</td>
#       <td id="T_ed407_row9_col5" class="data row9 col5" >0.5243</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ed407_row10_col0" class="data row10 col0" >9.2507</td>
#       <td id="T_ed407_row10_col1" class="data row10 col1" >202.8660</td>
#       <td id="T_ed407_row10_col2" class="data row10 col2" >14.2428</td>
#       <td id="T_ed407_row10_col3" class="data row10 col3" >0.7565</td>
#       <td id="T_ed407_row10_col4" class="data row10 col4" >0.4783</td>
#       <td id="T_ed407_row10_col5" class="data row10 col5" >0.5179</td>
#     </tr>
#     <tr>
#       <th id="T_ed407_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ed407_row11_col0" class="data row11 col0" >0.0511</td>
#       <td id="T_ed407_row11_col1" class="data row11 col1" >2.7368</td>
#       <td id="T_ed407_row11_col2" class="data row11 col2" >0.0958</td>
#       <td id="T_ed407_row11_col3" class="data row11 col3" >0.0035</td>
#       <td id="T_ed407_row11_col4" class="data row11 col4" >0.0054</td>
#       <td id="T_ed407_row11_col5" class="data row11 col5" >0.0122</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Output Data

# %%
# Output Full dataset
df.to_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/df_emo_full_pat.csv')

# %%
# Output Train and Test datasets
X_train.to_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/X_train.csv')
X_test.to_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/X_test.csv')
y_train.to_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/y_train.csv')
y_test.to_csv(r'/Users/harrisonchaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/y_test.csv')

# %% [markdown]
# ## 6. Summary

# %% [markdown]
# In this precprocessing and training step, we have created dummy variables for our categorical data (the song's decade label) and split our data into a train and test set. We will use 70% of the data for training and 30% for testing.
# As an initial exploration, we use PyCaret to analyze which models perform best. We run each of these models individually to check that their metrics are consistant across a 10-fold analysis.

# %% [markdown]
# In our next step, we will dig further into these top performing algorithms to create a finalized model that can help us best predict a Song's week position on the Billboard Top 100 chart.
