# %% [markdown]
# ## 0. Import Packages and Data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.linear_model import LogisticRegression
# import pycaret below <- automates the expiramentation process (test KNN, test logistic, etc...)
from pycaret.regression import setup, compare_models, create_model

# %%
# Import data that was output from previous notebook "2. Exploratory Data Analysis"
df = pd.read_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/df_emo_full_eda.csv', index_col = 0)

# %%
# Check that the details of this dataset make sense.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327895 entries, 0 to 327894
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WeekID                       327895 non-null  object
#  1   Week Position                327895 non-null  int64
#  2   Song                         327895 non-null  object
#  3   SongID                       327895 non-null  object
#  4   Instance                     327895 non-null  int64
#  5   Previous Week Position       327895 non-null  float64
#  6   Peak Position                327895 non-null  int64
#  7   Weeks on Chart               327895 non-null  int64
#  8   Artist                       327895 non-null  object
#  9   wordCount                    327895 non-null  float64
#  10  languages                    269355 non-null  object
#  11  allWordCount                 327895 non-null  float64
#  12  year                         327895 non-null  float64
#  13  decade                       327895 non-null  object
#  14  MTLD                         327895 non-null  float64
#  15  TTR                          327895 non-null  float64
#  16  CTTR                         327895 non-null  float64
#  17  sentimentScore               327895 non-null  float64
#  18  sentimentScore_pos           327895 non-null  float64
#  19  sentimentScore_neg           327895 non-null  float64
#  20  emoWordCount                 327895 non-null  float64
#  21  joy_normalized               327895 non-null  float64
#  22  sadness_normalized           327895 non-null  float64
#  23  anger_normalized             327895 non-null  float64
#  24  disgust_normalized           327895 non-null  float64
#  25  trust_normalized             327895 non-null  float64
#  26  anticipation_normalized      327895 non-null  float64
#  27  fear_normalized              327895 non-null  float64
#  28  surprise_normalized          327895 non-null  float64
#  29  emo_score                    327895 non-null  float64
#  30  happy_normalized             327895 non-null  float64
#  31  sorrow_normalized            327895 non-null  float64
#  32  YearID                       327895 non-null  int64
#  33  DecadeID                     327895 non-null  object
#  34  SuccessInd                   327895 non-null  int64
#  35  PrimaryKey                   327895 non-null  object
#  36  Week_dt                      327895 non-null  object
#  37  Week_dt_next                 327895 non-null  object
#  38  YearID_next                  327895 non-null  int64
#  39  Artist_Count_Total           327895 non-null  int64
#  40  Artist_Count_Year            327895 non-null  int64
#  41  Artist_Count_Year_prior      327895 non-null  float64
#  42  Artist_Count_Week            327895 non-null  int64
#  43  Artist_Count_Week_prior      327895 non-null  float64
#  44  joy_normalized_ind           327895 non-null  int64
#  45  sadness_normalized_ind       327895 non-null  int64
#  46  anger_normalized_ind         327895 non-null  int64
#  47  disgust_normalized_ind       327895 non-null  int64
#  48  trust_normalized_ind         327895 non-null  int64
#  49  anticipation_normalized_ind  327895 non-null  int64
#  50  fear_normalized_ind          327895 non-null  int64
#  51  surprise_normalized_ind      327895 non-null  int64
#  52  happy_normalized_ind         327895 non-null  int64
#  53  sorrow_normalized_ind        327895 non-null  int64
# dtypes: float64(24), int64(20), object(10)
# memory usage: 137.6+ MB

# %% [markdown]
# From the above, it appears that "decade" is the only object variable that needs to be transformed for modeling. All others objects, such as Week, SongID, and Artist are index related.

# %%
# Convert Decade Object Variable to Dummies
decade_dummies = pd.get_dummies(df['decade'])
df.drop("decade", axis = 1, inplace = True)
df = df.join(decade_dummies)

# %%
#Check that the Decade dummies are as expected
df.dtypes
# Out:
# WeekID           object
# Week Position     int64
# Song             object
# SongID           object
# Instance          int64
#                   ...
# 50s               uint8
# 60s               uint8
# 70s               uint8
# 80s               uint8
# 90s               uint8
# Length: 61, dtype: object

# %%
# Remove unnecessary columns, particularly the columns we are not interested in using.
df.drop(columns = ['joy_normalized', 'sadness_normalized', 'anger_normalized', 'disgust_normalized', 'trust_normalized', 'anticipation_normalized', 'fear_normalized', 'surprise_normalized', 'happy_normalized', 'sorrow_normalized', 'Week_dt', 'Week_dt_next', 'YearID_next', 'languages'], inplace = True)
# Check that these columns are removed.
df.dtypes
# Out:
# WeekID                          object
# Week Position                    int64
# Song                            object
# SongID                          object
# Instance                         int64
# Previous Week Position         float64
# Peak Position                    int64
# Weeks on Chart                   int64
# Artist                          object
# wordCount                      float64
# allWordCount                   float64
# year                           float64
# MTLD                           float64
# TTR                            float64
# CTTR                           float64
# sentimentScore                 float64
# sentimentScore_pos             float64
# sentimentScore_neg             float64
# emoWordCount                   float64
# emo_score                      float64
# YearID                           int64
# DecadeID                        object
# SuccessInd                       int64
# PrimaryKey                      object
# Artist_Count_Total               int64
# Artist_Count_Year                int64
# Artist_Count_Year_prior        float64
# Artist_Count_Week                int64
# Artist_Count_Week_prior        float64
# joy_normalized_ind               int64
# sadness_normalized_ind           int64
# anger_normalized_ind             int64
# disgust_normalized_ind           int64
# trust_normalized_ind             int64
# anticipation_normalized_ind      int64
# fear_normalized_ind              int64
# surprise_normalized_ind          int64
# happy_normalized_ind             int64
# sorrow_normalized_ind            int64
# 00s                              uint8
# 10s                              uint8
# 20s                              uint8
# 50s                              uint8
# 60s                              uint8
# 70s                              uint8
# 80s                              uint8
# 90s                              uint8
# dtype: object

# %% [markdown]
# ## 1. Train-Test Split

# %%
# Create a Train and Test dataset. 70% will be used for training.
## Week position will be our observed column.
len(df) * .7, len(df) * .3

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='Week Position'), 
                                                    df['Week Position'], test_size=0.3, 
                                                    random_state=123)

# %%
# Check our training set.
X_train.shape, X_test.shape
# Out:
# ((229526, 46), (98369, 46))

# %%
# Check our test set.
y_train.shape, y_test.shape
# Out:
# ((229526,), (98369,))

# %%
# Do the ratios of 'Week Position' match across Train and Test sets?
print(y_train.sum()/(len(X_train) + len(y_train)))
print(y_test.sum()/(len(X_test) + len(y_test)))
# Out:
# 25.216724902625412
# 25.326490052760523

# %% [markdown]
# ## 2. Remove PrimaryKey columns from Train & Test data

# %%
#Save the 'Week Position', 'Song', 'SongID', 'Artist', 'languages', 'year', 'PrimaryKey', 'DecadeID' columns from the train/test data into names_train and names_test
#Then drop those columns from `X_train` and `X_test`. Use 'inplace=True'
names_list = ['SuccessInd', 'Song', 'SongID', 'Artist', 'year', 'PrimaryKey', 'WeekID', 'DecadeID', 'YearID', 'Peak Position']
names_train = X_train[names_list]
names_test = X_test[names_list]
X_train.drop(columns=names_list, inplace=True)
X_test.drop(columns=names_list, inplace=True)
X_train.shape, X_test.shape
# Out:
# ((229526, 36), (98369, 36))

# %% [markdown]
# ## 3. Utilize pycaret

# %% [markdown]
# ### 3a. Run pycaret on all features

# %%
# Create dataset for pycaret analysis. We will use our entire dataset for this analysis.
df_2 = df.drop(columns = names_list)

# %%
# Set up the dataset.
grid = setup(data = df_2, target = 'Week Position')
# Out:
# <style type="text/css">
# #T_0d50e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0d50e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d50e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0d50e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d50e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d50e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0d50e_row0_col1" class="data row0 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d50e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0d50e_row1_col1" class="data row1 col1" >Week Position</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d50e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0d50e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d50e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0d50e_row3_col1" class="data row3 col1" >(327895, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d50e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0d50e_row4_col1" class="data row4 col1" >(327895, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d50e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0d50e_row5_col1" class="data row5 col1" >(229526, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d50e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0d50e_row6_col1" class="data row6 col1" >(98369, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d50e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0d50e_row7_col1" class="data row7 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0d50e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_0d50e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0d50e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_0d50e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0d50e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_0d50e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0d50e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_0d50e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0d50e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_0d50e_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0d50e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_0d50e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0d50e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_0d50e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0d50e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_0d50e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0d50e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_0d50e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0d50e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_0d50e_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0d50e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0d50e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_0d50e_row18_col1" class="data row18 col1" >66d0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Evaluate and compare models
best = compare_models(fold = 5, n_select = 5)
# Out:
# <style type="text/css">
# #T_96af7 th {
#   text-align: left;
# }
# #T_96af7_row0_col0, #T_96af7_row0_col5, #T_96af7_row1_col0, #T_96af7_row1_col1, #T_96af7_row1_col2, #T_96af7_row1_col3, #T_96af7_row1_col4, #T_96af7_row1_col6, #T_96af7_row2_col0, #T_96af7_row2_col1, #T_96af7_row2_col2, #T_96af7_row2_col3, #T_96af7_row2_col4, #T_96af7_row2_col5, #T_96af7_row2_col6, #T_96af7_row3_col0, #T_96af7_row3_col1, #T_96af7_row3_col2, #T_96af7_row3_col3, #T_96af7_row3_col4, #T_96af7_row3_col5, #T_96af7_row3_col6, #T_96af7_row4_col0, #T_96af7_row4_col1, #T_96af7_row4_col2, #T_96af7_row4_col3, #T_96af7_row4_col4, #T_96af7_row4_col5, #T_96af7_row4_col6, #T_96af7_row5_col0, #T_96af7_row5_col1, #T_96af7_row5_col2, #T_96af7_row5_col3, #T_96af7_row5_col4, #T_96af7_row5_col5, #T_96af7_row5_col6, #T_96af7_row6_col0, #T_96af7_row6_col1, #T_96af7_row6_col2, #T_96af7_row6_col3, #T_96af7_row6_col4, #T_96af7_row6_col5, #T_96af7_row6_col6, #T_96af7_row7_col0, #T_96af7_row7_col1, #T_96af7_row7_col2, #T_96af7_row7_col3, #T_96af7_row7_col4, #T_96af7_row7_col5, #T_96af7_row7_col6, #T_96af7_row8_col0, #T_96af7_row8_col1, #T_96af7_row8_col2, #T_96af7_row8_col3, #T_96af7_row8_col4, #T_96af7_row8_col5, #T_96af7_row8_col6, #T_96af7_row9_col0, #T_96af7_row9_col1, #T_96af7_row9_col2, #T_96af7_row9_col3, #T_96af7_row9_col4, #T_96af7_row9_col5, #T_96af7_row9_col6, #T_96af7_row10_col0, #T_96af7_row10_col1, #T_96af7_row10_col2, #T_96af7_row10_col3, #T_96af7_row10_col4, #T_96af7_row10_col5, #T_96af7_row10_col6, #T_96af7_row11_col0, #T_96af7_row11_col1, #T_96af7_row11_col2, #T_96af7_row11_col3, #T_96af7_row11_col4, #T_96af7_row11_col5, #T_96af7_row11_col6, #T_96af7_row12_col0, #T_96af7_row12_col1, #T_96af7_row12_col2, #T_96af7_row12_col3, #T_96af7_row12_col4, #T_96af7_row12_col5, #T_96af7_row12_col6, #T_96af7_row13_col0, #T_96af7_row13_col1, #T_96af7_row13_col2, #T_96af7_row13_col3, #T_96af7_row13_col4, #T_96af7_row13_col5, #T_96af7_row13_col6, #T_96af7_row14_col0, #T_96af7_row14_col1, #T_96af7_row14_col2, #T_96af7_row14_col3, #T_96af7_row14_col4, #T_96af7_row14_col5, #T_96af7_row14_col6, #T_96af7_row15_col0, #T_96af7_row15_col1, #T_96af7_row15_col2, #T_96af7_row15_col3, #T_96af7_row15_col4, #T_96af7_row15_col5, #T_96af7_row15_col6, #T_96af7_row16_col0, #T_96af7_row16_col1, #T_96af7_row16_col2, #T_96af7_row16_col3, #T_96af7_row16_col4, #T_96af7_row16_col5, #T_96af7_row16_col6, #T_96af7_row17_col0, #T_96af7_row17_col1, #T_96af7_row17_col2, #T_96af7_row17_col3, #T_96af7_row17_col4, #T_96af7_row17_col5, #T_96af7_row17_col6, #T_96af7_row18_col0, #T_96af7_row18_col1, #T_96af7_row18_col2, #T_96af7_row18_col3, #T_96af7_row18_col4, #T_96af7_row18_col5, #T_96af7_row18_col6 {
#   text-align: left;
# }
# #T_96af7_row0_col1, #T_96af7_row0_col2, #T_96af7_row0_col3, #T_96af7_row0_col4, #T_96af7_row0_col6, #T_96af7_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_96af7_row0_col7, #T_96af7_row1_col7, #T_96af7_row2_col7, #T_96af7_row3_col7, #T_96af7_row4_col7, #T_96af7_row5_col7, #T_96af7_row6_col7, #T_96af7_row7_col7, #T_96af7_row8_col7, #T_96af7_row9_col7, #T_96af7_row10_col7, #T_96af7_row11_col7, #T_96af7_row12_col7, #T_96af7_row14_col7, #T_96af7_row15_col7, #T_96af7_row16_col7, #T_96af7_row17_col7, #T_96af7_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_96af7_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_96af7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96af7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96af7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_96af7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_96af7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_96af7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_96af7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_96af7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_96af7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96af7_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_96af7_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_96af7_row0_col1" class="data row0 col1" >5.7055</td>
#       <td id="T_96af7_row0_col2" class="data row0 col2" >76.8578</td>
#       <td id="T_96af7_row0_col3" class="data row0 col3" >8.7667</td>
#       <td id="T_96af7_row0_col4" class="data row0 col4" >0.9079</td>
#       <td id="T_96af7_row0_col5" class="data row0 col5" >0.2413</td>
#       <td id="T_96af7_row0_col6" class="data row0 col6" >0.2027</td>
#       <td id="T_96af7_row0_col7" class="data row0 col7" >7.5700</td>
#     </tr>
#     <tr>
#       <th id="T_96af7_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_96af7_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_96af7_row1_col1" class="data row1 col1" >5.7869</td>
#       <td id="T_96af7_row1_col2" class="data row1 col2" >78.7547</td>
#       <td id="T_96af7_row1_col3" class="data row1 col3" >8.8743</td>
#       <td id="T_96af7_row1_col4" class="data row1 col4" >0.9056</td>
#       <td id="T_96af7_row1_col5" class="data row1 col5" >0.2406</td>
#       <td id="T_96af7_row1_col6" class="data row1 col6" >0.2064</td>
#       <td id="T_96af7_row1_col7" class="data row1 col7" >1.3560</td>
#     </tr>
#     <tr>
#       <th id="T_96af7_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_96af7_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_96af7_row2_col1" class="data row2 col1" >5.9214</td>
#       <td id="T_96af7_row2_col2" class="data row2 col2" >82.1829</td>
#       <td id="T_96af7_row2_col3" class="data row2 col3" >9.0654</td>
#       <td id="T_96af7_row2_col4" class="data row2 col4" >0.9015</td>
#       <td id="T_96af7_row2_col5" class="data row2 col5" >0.2434</td>
#       <td id="T_96af7_row2_col6" class="data row2 col6" >0.2038</td>
#       <td id="T_96af7_row2_col7" class="data row2 col7" >54.5460</td>
#     </tr>
#     <tr>
#       <th id="T_96af7_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_96af7_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_96af7_row3_col1" class="data row3 col1" >6.0936</td>
#       <td id="T_96af7_row3_col2" class="data row3 col2" >86.1485</td>
#       <td id="T_96af7_row3_col3" class="data row3 col3" >9.2816</td>
#       <td id="T_96af7_row3_col4" class="data row3 col4" >0.8967</td>
#       <td id="T_96af7_row3_col5" class="data row3 col5" >0.2490</td>
#       <td id="T_96af7_row3_col6" class="data row3 col6" >0.2075</td>
#       <td id="T_96af7_row3_col7" class="data row3 col7" >66.0480</td>
#     </tr>
#     <tr>
#       <th id="T_96af7_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_96af7_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_96af7_row4_col1" class="data row4 col1" >6.1121</td>
#       <td id="T_96af7_row4_col2" class="data row4 col2" >87.5695</td>
#       <td id="T_96af7_row4_col3" class="data row4 col3" >9.3577</td>
#       <td id="T_96af7_row4_col4" class="data row4 col4" >0.8950</td>
#       <td id="T_96af7_row4_col5" class="data row4 col5" >0.2565</td>
#       <td id="T_96af7_row4_col6" class="data row4 col6" >0.2267</td>
#       <td id="T_96af7_row4_col7" class="data row4 col7" >14.6020</td>
#     </tr>
#     <tr>
#       <th id="T_96af7_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_96af7_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_96af7_row5_col1" class="data row5 col1" >8.2671</td>
#       <td id="T_96af7_row5_col2" class="data row5 col2" >143.3877</td>
#       <td id="T_96af7_row5_col3" class="data row5 col3" >11.9744</td>
#       <td id="T_96af7_row5_col4" class="data row5 col4" >0.8281</td>
#       <td id="T_96af7_row5_col5" class="data row5 col5" >0.3494</td>
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# The top 5 models for all factors based on MSE, RMSE, and R2 are CatBoost, Light Gradient Boosting Machine, Random Forest, Extra Trees, and Gradient Boosting.

# %% [markdown]
# ### 3b. Run pycaret on controlable features

# %%
# Create dataset for pycaret analysis. We will use ONLY CONTROLABLE dataset for this analysis.
df_2 = df.drop(columns = names_list)
df_2 = df_2.drop(columns = {'Instance', 'Previous Week Position', 'Weeks on Chart', 'Artist_Count_Total', 'Artist_Count_Year', 'Artist_Count_Year_prior', 'Artist_Count_Week', 'Artist_Count_Week_prior', '00s', '10s', '20s', '50s', '60s', '70s', '80s', '90s'})
print(df_2.columns)
# Out:
# Index(['Week Position', 'wordCount', 'allWordCount', 'MTLD', 'TTR', 'CTTR',
#        'sentimentScore', 'sentimentScore_pos', 'sentimentScore_neg',
#        'emoWordCount', 'emo_score', 'joy_normalized_ind',
#        'sadness_normalized_ind', 'anger_normalized_ind',
#        'disgust_normalized_ind', 'trust_normalized_ind',
#        'anticipation_normalized_ind', 'fear_normalized_ind',
#        'surprise_normalized_ind', 'happy_normalized_ind',
#        'sorrow_normalized_ind'],
#       dtype='object')

# %%
# Set up the dataset.
grid = setup(data = df_2, target = 'Week Position')
# Out:
# <style type="text/css">
# #T_06b5c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_06b5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06b5c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_06b5c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06b5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06b5c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_06b5c_row0_col1" class="data row0 col1" >6645</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06b5c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_06b5c_row1_col1" class="data row1 col1" >Week Position</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06b5c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_06b5c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06b5c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_06b5c_row3_col1" class="data row3 col1" >(327895, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06b5c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_06b5c_row4_col1" class="data row4 col1" >(327895, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06b5c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_06b5c_row5_col1" class="data row5 col1" >(229526, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06b5c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_06b5c_row6_col1" class="data row6 col1" >(98369, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06b5c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_06b5c_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06b5c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_06b5c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06b5c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_06b5c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_06b5c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_06b5c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_06b5c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_06b5c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_06b5c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_06b5c_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_06b5c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_06b5c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_06b5c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_06b5c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_06b5c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_06b5c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_06b5c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_06b5c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_06b5c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_06b5c_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_06b5c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_06b5c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_06b5c_row18_col1" class="data row18 col1" >1600</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Evaluate and compare models
best = compare_models(fold = 5, n_select = 5)
# Out:
# <style type="text/css">
# #T_0777c th {
#   text-align: left;
# }
# #T_0777c_row0_col0, #T_0777c_row0_col5, #T_0777c_row1_col0, #T_0777c_row1_col1, #T_0777c_row1_col2, #T_0777c_row1_col3, #T_0777c_row1_col4, #T_0777c_row1_col6, #T_0777c_row2_col0, #T_0777c_row2_col1, #T_0777c_row2_col2, #T_0777c_row2_col3, #T_0777c_row2_col4, #T_0777c_row2_col5, #T_0777c_row2_col6, #T_0777c_row3_col0, #T_0777c_row3_col1, #T_0777c_row3_col2, #T_0777c_row3_col3, #T_0777c_row3_col4, #T_0777c_row3_col5, #T_0777c_row3_col6, #T_0777c_row4_col0, #T_0777c_row4_col1, #T_0777c_row4_col2, #T_0777c_row4_col3, #T_0777c_row4_col4, #T_0777c_row4_col5, #T_0777c_row4_col6, #T_0777c_row5_col0, #T_0777c_row5_col1, #T_0777c_row5_col2, #T_0777c_row5_col3, #T_0777c_row5_col4, #T_0777c_row5_col5, #T_0777c_row5_col6, #T_0777c_row6_col0, #T_0777c_row6_col1, #T_0777c_row6_col2, #T_0777c_row6_col3, #T_0777c_row6_col4, #T_0777c_row6_col5, #T_0777c_row6_col6, #T_0777c_row7_col0, #T_0777c_row7_col1, #T_0777c_row7_col2, #T_0777c_row7_col3, #T_0777c_row7_col4, #T_0777c_row7_col5, #T_0777c_row7_col6, #T_0777c_row8_col0, #T_0777c_row8_col1, #T_0777c_row8_col2, #T_0777c_row8_col3, #T_0777c_row8_col4, #T_0777c_row8_col5, #T_0777c_row8_col6, #T_0777c_row9_col0, #T_0777c_row9_col1, #T_0777c_row9_col2, #T_0777c_row9_col3, #T_0777c_row9_col4, #T_0777c_row9_col5, #T_0777c_row9_col6, #T_0777c_row10_col0, #T_0777c_row10_col1, #T_0777c_row10_col2, #T_0777c_row10_col3, #T_0777c_row10_col4, #T_0777c_row10_col5, #T_0777c_row10_col6, #T_0777c_row11_col0, #T_0777c_row11_col1, #T_0777c_row11_col2, #T_0777c_row11_col3, #T_0777c_row11_col4, #T_0777c_row11_col5, #T_0777c_row11_col6, #T_0777c_row12_col0, #T_0777c_row12_col1, #T_0777c_row12_col2, #T_0777c_row12_col3, #T_0777c_row12_col4, #T_0777c_row12_col5, #T_0777c_row12_col6, #T_0777c_row13_col0, #T_0777c_row13_col1, #T_0777c_row13_col2, #T_0777c_row13_col3, #T_0777c_row13_col4, #T_0777c_row13_col5, #T_0777c_row13_col6, #T_0777c_row14_col0, #T_0777c_row14_col1, #T_0777c_row14_col2, #T_0777c_row14_col3, #T_0777c_row14_col4, #T_0777c_row14_col5, #T_0777c_row14_col6, #T_0777c_row15_col0, #T_0777c_row15_col1, #T_0777c_row15_col2, #T_0777c_row15_col3, #T_0777c_row15_col4, #T_0777c_row15_col5, #T_0777c_row15_col6, #T_0777c_row16_col0, #T_0777c_row16_col1, #T_0777c_row16_col2, #T_0777c_row16_col3, #T_0777c_row16_col4, #T_0777c_row16_col5, #T_0777c_row16_col6, #T_0777c_row17_col0, #T_0777c_row17_col1, #T_0777c_row17_col2, #T_0777c_row17_col3, #T_0777c_row17_col4, #T_0777c_row17_col5, #T_0777c_row17_col6, #T_0777c_row18_col0, #T_0777c_row18_col1, #T_0777c_row18_col2, #T_0777c_row18_col3, #T_0777c_row18_col4, #T_0777c_row18_col5, #T_0777c_row18_col6 {
#   text-align: left;
# }
# #T_0777c_row0_col1, #T_0777c_row0_col2, #T_0777c_row0_col3, #T_0777c_row0_col4, #T_0777c_row0_col6, #T_0777c_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0777c_row0_col7, #T_0777c_row1_col7, #T_0777c_row2_col7, #T_0777c_row3_col7, #T_0777c_row4_col7, #T_0777c_row5_col7, #T_0777c_row6_col7, #T_0777c_row7_col7, #T_0777c_row8_col7, #T_0777c_row9_col7, #T_0777c_row10_col7, #T_0777c_row11_col7, #T_0777c_row12_col7, #T_0777c_row13_col7, #T_0777c_row14_col7, #T_0777c_row15_col7, #T_0777c_row17_col7, #T_0777c_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0777c_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0777c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0777c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0777c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0777c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0777c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0777c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0777c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0777c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0777c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0777c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_0777c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_0777c_row0_col1" class="data row0 col1" >18.1790</td>
#       <td id="T_0777c_row0_col2" class="data row0 col2" >523.5849</td>
#       <td id="T_0777c_row0_col3" class="data row0 col3" >22.8819</td>
#       <td id="T_0777c_row0_col4" class="data row0 col4" >0.3712</td>
#       <td id="T_0777c_row0_col5" class="data row0 col5" >0.7147</td>
#       <td id="T_0777c_row0_col6" class="data row0 col6" >1.1297</td>
#       <td id="T_0777c_row0_col7" class="data row0 col7" >9.3220</td>
#     </tr>
#     <tr>
#       <th id="T_0777c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0777c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_0777c_row1_col1" class="data row1 col1" >18.2429</td>
#       <td id="T_0777c_row1_col2" class="data row1 col2" >523.7808</td>
#       <td id="T_0777c_row1_col3" class="data row1 col3" >22.8862</td>
#       <td id="T_0777c_row1_col4" class="data row1 col4" >0.3710</td>
#       <td id="T_0777c_row1_col5" class="data row1 col5" >0.7144</td>
#       <td id="T_0777c_row1_col6" class="data row1 col6" >1.1314</td>
#       <td id="T_0777c_row1_col7" class="data row1 col7" >18.1480</td>
#     </tr>
#     <tr>
#       <th id="T_0777c_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_0777c_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_0777c_row2_col1" class="data row2 col1" >18.2369</td>
#       <td id="T_0777c_row2_col2" class="data row2 col2" >530.7099</td>
#       <td id="T_0777c_row2_col3" class="data row2 col3" >23.0370</td>
#       <td id="T_0777c_row2_col4" class="data row2 col4" >0.3626</td>
#       <td id="T_0777c_row2_col5" class="data row2 col5" >0.7173</td>
#       <td id="T_0777c_row2_col6" class="data row2 col6" >1.1306</td>
#       <td id="T_0777c_row2_col7" class="data row2 col7" >1.3360</td>
#     </tr>
#     <tr>
#       <th id="T_0777c_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_0777c_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_0777c_row3_col1" class="data row3 col1" >19.4559</td>
#       <td id="T_0777c_row3_col2" class="data row3 col2" >607.4218</td>
#       <td id="T_0777c_row3_col3" class="data row3 col3" >24.6449</td>
#       <td id="T_0777c_row3_col4" class="data row3 col4" >0.2705</td>
#       <td id="T_0777c_row3_col5" class="data row3 col5" >0.7427</td>
#       <td id="T_0777c_row3_col6" class="data row3 col6" >1.1601</td>
#       <td id="T_0777c_row3_col7" class="data row3 col7" >641.5360</td>
#     </tr>
#     <tr>
#       <th id="T_0777c_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_0777c_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_0777c_row4_col1" class="data row4 col1" >22.3702</td>
#       <td id="T_0777c_row4_col2" class="data row4 col2" >689.6900</td>
#       <td id="T_0777c_row4_col3" class="data row4 col3" >26.2619</td>
#       <td id="T_0777c_row4_col4" class="data row4 col4" >0.1717</td>
#       <td id="T_0777c_row4_col5" class="data row4 col5" >0.8279</td>
#       <td id="T_0777c_row4_col6" class="data row4 col6" >1.6403</td>
#       <td id="T_0777c_row4_col7" class="data row4 col7" >5.0860</td>
#     </tr>
#     <tr>
#       <th id="T_0777c_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_0777c_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0777c_row5_col1" class="data row5 col1" >23.6068</td>
#       <td id="T_0777c_row5_col2" class="data row5 col2" >754.8686</td>
#       <td id="T_0777c_row5_col3" class="data row5 col3" >27.4748</td>
#       <td id="T_0777c_row5_col4" class="data row5 col4" >0.0934</td>
#       <td id="T_0777c_row5_col5" class="data row5 col5" >0.859
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# The top 5 models for controlable factors are Extra Trees Regressor, Random Forest, Decision Tree, KNN, and CatBoost.

# %% [markdown]
# ## 4. Test Top Algorithms

# %% [markdown]
# Test the top performing algorithms to check metrics on 10-fold and analyze whether or not they perform consistently.

# %% [markdown]
# ### 4a. CatBoost Gradient Boosting

# %%
catboost = create_model("catboost")
# Out:
# <style type="text/css">
# #T_878e6_row10_col0, #T_878e6_row10_col1, #T_878e6_row10_col2, #T_878e6_row10_col3, #T_878e6_row10_col4, #T_878e6_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_878e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_878e6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_878e6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_878e6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_878e6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_878e6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_878e6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_878e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_878e6_row0_col0" class="data row0 col0" >22.1964</td>
#       <td id="T_878e6_row0_col1" class="data row0 col1" >681.9013</td>
#       <td id="T_878e6_row0_col2" class="data row0 col2" >26.1132</td>
#       <td id="T_878e6_row0_col3" class="data row0 col3" >0.1768</td>
#       <td id="T_878e6_row0_col4" class="data row0 col4" >0.8240</td>
#       <td id="T_878e6_row0_col5" class="data row0 col5" >1.6193</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_878e6_row1_col0" class="data row1 col0" >22.2893</td>
#       <td id="T_878e6_row1_col1" class="data row1 col1" >684.4733</td>
#       <td id="T_878e6_row1_col2" class="data row1 col2" >26.1624</td>
#       <td id="T_878e6_row1_col3" class="data row1 col3" >0.1805</td>
#       <td id="T_878e6_row1_col4" class="data row1 col4" >0.8265</td>
#       <td id="T_878e6_row1_col5" class="data row1 col5" >1.6457</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_878e6_row2_col0" class="data row2 col0" >22.3927</td>
#       <td id="T_878e6_row2_col1" class="data row2 col1" >690.4362</td>
#       <td id="T_878e6_row2_col2" class="data row2 col2" >26.2762</td>
#       <td id="T_878e6_row2_col3" class="data row2 col3" >0.1702</td>
#       <td id="T_878e6_row2_col4" class="data row2 col4" >0.8224</td>
#       <td id="T_878e6_row2_col5" class="data row2 col5" >1.6184</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_878e6_row3_col0" class="data row3 col0" >22.2942</td>
#       <td id="T_878e6_row3_col1" class="data row3 col1" >683.9966</td>
#       <td id="T_878e6_row3_col2" class="data row3 col2" >26.1533</td>
#       <td id="T_878e6_row3_col3" class="data row3 col3" >0.1781</td>
#       <td id="T_878e6_row3_col4" class="data row3 col4" >0.8248</td>
#       <td id="T_878e6_row3_col5" class="data row3 col5" >1.6455</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_878e6_row4_col0" class="data row4 col0" >22.3064</td>
#       <td id="T_878e6_row4_col1" class="data row4 col1" >685.0102</td>
#       <td id="T_878e6_row4_col2" class="data row4 col2" >26.1727</td>
#       <td id="T_878e6_row4_col3" class="data row4 col3" >0.1787</td>
#       <td id="T_878e6_row4_col4" class="data row4 col4" >0.8329</td>
#       <td id="T_878e6_row4_col5" class="data row4 col5" >1.6907</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_878e6_row5_col0" class="data row5 col0" >22.4475</td>
#       <td id="T_878e6_row5_col1" class="data row5 col1" >694.7680</td>
#       <td id="T_878e6_row5_col2" class="data row5 col2" >26.3585</td>
#       <td id="T_878e6_row5_col3" class="data row5 col3" >0.1692</td>
#       <td id="T_878e6_row5_col4" class="data row5 col4" >0.8375</td>
#       <td id="T_878e6_row5_col5" class="data row5 col5" >1.6790</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_878e6_row6_col0" class="data row6 col0" >22.2250</td>
#       <td id="T_878e6_row6_col1" class="data row6 col1" >681.6823</td>
#       <td id="T_878e6_row6_col2" class="data row6 col2" >26.1090</td>
#       <td id="T_878e6_row6_col3" class="data row6 col3" >0.1791</td>
#       <td id="T_878e6_row6_col4" class="data row6 col4" >0.8221</td>
#       <td id="T_878e6_row6_col5" class="data row6 col5" >1.6093</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_878e6_row7_col0" class="data row7 col0" >22.1825</td>
#       <td id="T_878e6_row7_col1" class="data row7 col1" >678.6252</td>
#       <td id="T_878e6_row7_col2" class="data row7 col2" >26.0504</td>
#       <td id="T_878e6_row7_col3" class="data row7 col3" >0.1818</td>
#       <td id="T_878e6_row7_col4" class="data row7 col4" >0.8239</td>
#       <td id="T_878e6_row7_col5" class="data row7 col5" >1.6362</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_878e6_row8_col0" class="data row8 col0" >22.3374</td>
#       <td id="T_878e6_row8_col1" class="data row8 col1" >686.5517</td>
#       <td id="T_878e6_row8_col2" class="data row8 col2" >26.2021</td>
#       <td id="T_878e6_row8_col3" class="data row8 col3" >0.1768</td>
#       <td id="T_878e6_row8_col4" class="data row8 col4" >0.8263</td>
#       <td id="T_878e6_row8_col5" class="data row8 col5" >1.6055</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_878e6_row9_col0" class="data row9 col0" >22.3768</td>
#       <td id="T_878e6_row9_col1" class="data row9 col1" >689.9119</td>
#       <td id="T_878e6_row9_col2" class="data row9 col2" >26.2662</td>
#       <td id="T_878e6_row9_col3" class="data row9 col3" >0.1733</td>
#       <td id="T_878e6_row9_col4" class="data row9 col4" >0.8225</td>
#       <td id="T_878e6_row9_col5" class="data row9 col5" >1.5922</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_878e6_row10_col0" class="data row10 col0" >22.3048</td>
#       <td id="T_878e6_row10_col1" class="data row10 col1" >685.7357</td>
#       <td id="T_878e6_row10_col2" class="data row10 col2" >26.1864</td>
#       <td id="T_878e6_row10_col3" class="data row10 col3" >0.1765</td>
#       <td id="T_878e6_row10_col4" class="data row10 col4" >0.8263</td>
#       <td id="T_878e6_row10_col5" class="data row10 col5" >1.6342</td>
#     </tr>
#     <tr>
#       <th id="T_878e6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_878e6_row11_col0" class="data row11 col0" >0.0823</td>
#       <td id="T_878e6_row11_col1" class="data row11 col1" >4.5675</td>
#       <td id="T_878e6_row11_col2" class="data row11 col2" >0.0871</td>
#       <td id="T_878e6_row11_col3" class="data row11 col3" >0.0040</td>
#       <td id="T_878e6_row11_col4" class="data row11 col4" >0.0048</td>
#       <td id="T_878e6_row11_col5" class="data row11 col5" >0.0302</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 4b. Light Gradient Boosting Machine

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_8b969_row10_col0, #T_8b969_row10_col1, #T_8b969_row10_col2, #T_8b969_row10_col3, #T_8b969_row10_col4, #T_8b969_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8b969">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b969_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8b969_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8b969_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8b969_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8b969_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8b969_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b969_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b969_row0_col0" class="data row0 col0" >23.4811</td>
#       <td id="T_8b969_row0_col1" class="data row0 col1" >749.8421</td>
#       <td id="T_8b969_row0_col2" class="data row0 col2" >27.3832</td>
#       <td id="T_8b969_row0_col3" class="data row0 col3" >0.0948</td>
#       <td id="T_8b969_row0_col4" class="data row0 col4" >0.8568</td>
#       <td id="T_8b969_row0_col5" class="data row0 col5" >1.7626</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b969_row1_col0" class="data row1 col0" >23.6068</td>
#       <td id="T_8b969_row1_col1" class="data row1 col1" >753.7035</td>
#       <td id="T_8b969_row1_col2" class="data row1 col2" >27.4537</td>
#       <td id="T_8b969_row1_col3" class="data row1 col3" >0.0976</td>
#       <td id="T_8b969_row1_col4" class="data row1 col4" >0.8587</td>
#       <td id="T_8b969_row1_col5" class="data row1 col5" >1.7875</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b969_row2_col0" class="data row2 col0" >23.6862</td>
#       <td id="T_8b969_row2_col1" class="data row2 col1" >759.8163</td>
#       <td id="T_8b969_row2_col2" class="data row2 col2" >27.5648</td>
#       <td id="T_8b969_row2_col3" class="data row2 col3" >0.0868</td>
#       <td id="T_8b969_row2_col4" class="data row2 col4" >0.8546</td>
#       <td id="T_8b969_row2_col5" class="data row2 col5" >1.7554</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b969_row3_col0" class="data row3 col0" >23.6297</td>
#       <td id="T_8b969_row3_col1" class="data row3 col1" >754.3100</td>
#       <td id="T_8b969_row3_col2" class="data row3 col2" >27.4647</td>
#       <td id="T_8b969_row3_col3" class="data row3 col3" >0.0936</td>
#       <td id="T_8b969_row3_col4" class="data row3 col4" >0.8578</td>
#       <td id="T_8b969_row3_col5" class="data row3 col5" >1.7930</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b969_row4_col0" class="data row4 col0" >23.5952</td>
#       <td id="T_8b969_row4_col1" class="data row4 col1" >754.3539</td>
#       <td id="T_8b969_row4_col2" class="data row4 col2" >27.4655</td>
#       <td id="T_8b969_row4_col3" class="data row4 col3" >0.0955</td>
#       <td id="T_8b969_row4_col4" class="data row4 col4" >0.8656</td>
#       <td id="T_8b969_row4_col5" class="data row4 col5" >1.8381</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b969_row5_col0" class="data row5 col0" >23.6951</td>
#       <td id="T_8b969_row5_col1" class="data row5 col1" >760.2628</td>
#       <td id="T_8b969_row5_col2" class="data row5 col2" >27.5729</td>
#       <td id="T_8b969_row5_col3" class="data row5 col3" >0.0909</td>
#       <td id="T_8b969_row5_col4" class="data row5 col4" >0.8686</td>
#       <td id="T_8b969_row5_col5" class="data row5 col5" >1.8196</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b969_row6_col0" class="data row6 col0" >23.4875</td>
#       <td id="T_8b969_row6_col1" class="data row6 col1" >748.9943</td>
#       <td id="T_8b969_row6_col2" class="data row6 col2" >27.3678</td>
#       <td id="T_8b969_row6_col3" class="data row6 col3" >0.0981</td>
#       <td id="T_8b969_row6_col4" class="data row6 col4" >0.8546</td>
#       <td id="T_8b969_row6_col5" class="data row6 col5" >1.7497</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b969_row7_col0" class="data row7 col0" >23.4725</td>
#       <td id="T_8b969_row7_col1" class="data row7 col1" >747.4450</td>
#       <td id="T_8b969_row7_col2" class="data row7 col2" >27.3394</td>
#       <td id="T_8b969_row7_col3" class="data row7 col3" >0.0988</td>
#       <td id="T_8b969_row7_col4" class="data row7 col4" >0.8570</td>
#       <td id="T_8b969_row7_col5" class="data row7 col5" >1.7817</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8b969_row8_col0" class="data row8 col0" >23.6530</td>
#       <td id="T_8b969_row8_col1" class="data row8 col1" >754.6425</td>
#       <td id="T_8b969_row8_col2" class="data row8 col2" >27.4708</td>
#       <td id="T_8b969_row8_col3" class="data row8 col3" >0.0952</td>
#       <td id="T_8b969_row8_col4" class="data row8 col4" >0.8583</td>
#       <td id="T_8b969_row8_col5" class="data row8 col5" >1.7432</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8b969_row9_col0" class="data row9 col0" >23.6116</td>
#       <td id="T_8b969_row9_col1" class="data row9 col1" >754.8901</td>
#       <td id="T_8b969_row9_col2" class="data row9 col2" >27.4753</td>
#       <td id="T_8b969_row9_col3" class="data row9 col3" >0.0954</td>
#       <td id="T_8b969_row9_col4" class="data row9 col4" >0.8538</td>
#       <td id="T_8b969_row9_col5" class="data row9 col5" >1.7278</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8b969_row10_col0" class="data row10 col0" >23.5919</td>
#       <td id="T_8b969_row10_col1" class="data row10 col1" >753.8260</td>
#       <td id="T_8b969_row10_col2" class="data row10 col2" >27.4558</td>
#       <td id="T_8b969_row10_col3" class="data row10 col3" >0.0947</td>
#       <td id="T_8b969_row10_col4" class="data row10 col4" >0.8586</td>
#       <td id="T_8b969_row10_col5" class="data row10 col5" >1.7759</td>
#     </tr>
#     <tr>
#       <th id="T_8b969_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8b969_row11_col0" class="data row11 col0" >0.0792</td>
#       <td id="T_8b969_row11_col1" class="data row11 col1" >3.9947</td>
#       <td id="T_8b969_row11_col2" class="data row11 col2" >0.0727</td>
#       <td id="T_8b969_row11_col3" class="data row11 col3" >0.0034</td>
#       <td id="T_8b969_row11_col4" class="data row11 col4" >0.0046</td>
#       <td id="T_8b969_row11_col5" class="data row11 col5" >0.0330</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 4c. Random Forest

# %%
rf = create_model("rf")
# Out:
# <style type="text/css">
# #T_b1b92_row10_col0, #T_b1b92_row10_col1, #T_b1b92_row10_col2, #T_b1b92_row10_col3, #T_b1b92_row10_col4, #T_b1b92_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b1b92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1b92_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b1b92_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b1b92_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b1b92_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b1b92_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b1b92_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1b92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1b92_row0_col0" class="data row0 col0" >18.1016</td>
#       <td id="T_b1b92_row0_col1" class="data row0 col1" >514.9967</td>
#       <td id="T_b1b92_row0_col2" class="data row0 col2" >22.6935</td>
#       <td id="T_b1b92_row0_col3" class="data row0 col3" >0.3783</td>
#       <td id="T_b1b92_row0_col4" class="data row0 col4" >0.7097</td>
#       <td id="T_b1b92_row0_col5" class="data row0 col5" >1.1240</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1b92_row1_col0" class="data row1 col0" >18.1050</td>
#       <td id="T_b1b92_row1_col1" class="data row1 col1" >513.6264</td>
#       <td id="T_b1b92_row1_col2" class="data row1 col2" >22.6633</td>
#       <td id="T_b1b92_row1_col3" class="data row1 col3" >0.3850</td>
#       <td id="T_b1b92_row1_col4" class="data row1 col4" >0.7105</td>
#       <td id="T_b1b92_row1_col5" class="data row1 col5" >1.1303</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1b92_row2_col0" class="data row2 col0" >18.2975</td>
#       <td id="T_b1b92_row2_col1" class="data row2 col1" >526.6915</td>
#       <td id="T_b1b92_row2_col2" class="data row2 col2" >22.9498</td>
#       <td id="T_b1b92_row2_col3" class="data row2 col3" >0.3670</td>
#       <td id="T_b1b92_row2_col4" class="data row2 col4" >0.7134</td>
#       <td id="T_b1b92_row2_col5" class="data row2 col5" >1.1386</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1b92_row3_col0" class="data row3 col0" >18.0093</td>
#       <td id="T_b1b92_row3_col1" class="data row3 col1" >513.7961</td>
#       <td id="T_b1b92_row3_col2" class="data row3 col2" >22.6671</td>
#       <td id="T_b1b92_row3_col3" class="data row3 col3" >0.3826</td>
#       <td id="T_b1b92_row3_col4" class="data row3 col4" >0.7081</td>
#       <td id="T_b1b92_row3_col5" class="data row3 col5" >1.1289</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1b92_row4_col0" class="data row4 col0" >18.0451</td>
#       <td id="T_b1b92_row4_col1" class="data row4 col1" >513.4040</td>
#       <td id="T_b1b92_row4_col2" class="data row4 col2" >22.6584</td>
#       <td id="T_b1b92_row4_col3" class="data row4 col3" >0.3844</td>
#       <td id="T_b1b92_row4_col4" class="data row4 col4" >0.7129</td>
#       <td id="T_b1b92_row4_col5" class="data row4 col5" >1.1515</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1b92_row5_col0" class="data row5 col0" >18.2528</td>
#       <td id="T_b1b92_row5_col1" class="data row5 col1" >523.8741</td>
#       <td id="T_b1b92_row5_col2" class="data row5 col2" >22.8883</td>
#       <td id="T_b1b92_row5_col3" class="data row5 col3" >0.3736</td>
#       <td id="T_b1b92_row5_col4" class="data row5 col4" >0.7222</td>
#       <td id="T_b1b92_row5_col5" class="data row5 col5" >1.1616</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1b92_row6_col0" class="data row6 col0" >18.0911</td>
#       <td id="T_b1b92_row6_col1" class="data row6 col1" >515.8024</td>
#       <td id="T_b1b92_row6_col2" class="data row6 col2" >22.7113</td>
#       <td id="T_b1b92_row6_col3" class="data row6 col3" >0.3789</td>
#       <td id="T_b1b92_row6_col4" class="data row6 col4" >0.7100</td>
#       <td id="T_b1b92_row6_col5" class="data row6 col5" >1.1195</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1b92_row7_col0" class="data row7 col0" >17.9955</td>
#       <td id="T_b1b92_row7_col1" class="data row7 col1" >510.4134</td>
#       <td id="T_b1b92_row7_col2" class="data row7 col2" >22.5923</td>
#       <td id="T_b1b92_row7_col3" class="data row7 col3" >0.3846</td>
#       <td id="T_b1b92_row7_col4" class="data row7 col4" >0.7079</td>
#       <td id="T_b1b92_row7_col5" class="data row7 col5" >1.1172</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1b92_row8_col0" class="data row8 col0" >18.1593</td>
#       <td id="T_b1b92_row8_col1" class="data row8 col1" >520.5524</td>
#       <td id="T_b1b92_row8_col2" class="data row8 col2" >22.8156</td>
#       <td id="T_b1b92_row8_col3" class="data row8 col3" >0.3759</td>
#       <td id="T_b1b92_row8_col4" class="data row8 col4" >0.7146</td>
#       <td id="T_b1b92_row8_col5" class="data row8 col5" >1.1195</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1b92_row9_col0" class="data row9 col0" >18.1587</td>
#       <td id="T_b1b92_row9_col1" class="data row9 col1" >518.8127</td>
#       <td id="T_b1b92_row9_col2" class="data row9 col2" >22.7775</td>
#       <td id="T_b1b92_row9_col3" class="data row9 col3" >0.3783</td>
#       <td id="T_b1b92_row9_col4" class="data row9 col4" >0.7095</td>
#       <td id="T_b1b92_row9_col5" class="data row9 col5" >1.0941</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b1b92_row10_col0" class="data row10 col0" >18.1216</td>
#       <td id="T_b1b92_row10_col1" class="data row10 col1" >517.1970</td>
#       <td id="T_b1b92_row10_col2" class="data row10 col2" >22.7417</td>
#       <td id="T_b1b92_row10_col3" class="data row10 col3" >0.3789</td>
#       <td id="T_b1b92_row10_col4" class="data row10 col4" >0.7119</td>
#       <td id="T_b1b92_row10_col5" class="data row10 col5" >1.1285</td>
#     </tr>
#     <tr>
#       <th id="T_b1b92_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b1b92_row11_col0" class="data row11 col0" >0.0932</td>
#       <td id="T_b1b92_row11_col1" class="data row11 col1" >4.9000</td>
#       <td id="T_b1b92_row11_col2" class="data row11 col2" >0.1076</td>
#       <td id="T_b1b92_row11_col3" class="data row11 col3" >0.0054</td>
#       <td id="T_b1b92_row11_col4" class="data row11 col4" >0.0040</td>
#       <td id="T_b1b92_row11_col5" class="data row11 col5" >0.0179</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 4d. Gradient Boosting Regressor

# %%
gb = create_model("gbr")
# Out:
# <style type="text/css">
# #T_33325_row10_col0, #T_33325_row10_col1, #T_33325_row10_col2, #T_33325_row10_col3, #T_33325_row10_col4, #T_33325_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_33325">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33325_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_33325_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_33325_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_33325_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_33325_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_33325_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33325_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33325_row0_col0" class="data row0 col0" >24.2610</td>
#       <td id="T_33325_row0_col1" class="data row0 col1" >795.1144</td>
#       <td id="T_33325_row0_col2" class="data row0 col2" >28.1978</td>
#       <td id="T_33325_row0_col3" class="data row0 col3" >0.0402</td>
#       <td id="T_33325_row0_col4" class="data row0 col4" >0.8751</td>
#       <td id="T_33325_row0_col5" class="data row0 col5" >1.8419</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33325_row1_col0" class="data row1 col0" >24.4029</td>
#       <td id="T_33325_row1_col1" class="data row1 col1" >801.3621</td>
#       <td id="T_33325_row1_col2" class="data row1 col2" >28.3083</td>
#       <td id="T_33325_row1_col3" class="data row1 col3" >0.0405</td>
#       <td id="T_33325_row1_col4" class="data row1 col4" >0.8772</td>
#       <td id="T_33325_row1_col5" class="data row1 col5" >1.8693</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33325_row2_col0" class="data row2 col0" >24.4132</td>
#       <td id="T_33325_row2_col1" class="data row2 col1" >802.6223</td>
#       <td id="T_33325_row2_col2" class="data row2 col2" >28.3306</td>
#       <td id="T_33325_row2_col3" class="data row2 col3" >0.0354</td>
#       <td id="T_33325_row2_col4" class="data row2 col4" >0.8714</td>
#       <td id="T_33325_row2_col5" class="data row2 col5" >1.8257</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33325_row3_col0" class="data row3 col0" >24.4220</td>
#       <td id="T_33325_row3_col1" class="data row3 col1" >801.0979</td>
#       <td id="T_33325_row3_col2" class="data row3 col2" >28.3037</td>
#       <td id="T_33325_row3_col3" class="data row3 col3" >0.0374</td>
#       <td id="T_33325_row3_col4" class="data row3 col4" >0.8762</td>
#       <td id="T_33325_row3_col5" class="data row3 col5" >1.8730</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_33325_row4_col0" class="data row4 col0" >24.3931</td>
#       <td id="T_33325_row4_col1" class="data row4 col1" >800.3425</td>
#       <td id="T_33325_row4_col2" class="data row4 col2" >28.2903</td>
#       <td id="T_33325_row4_col3" class="data row4 col3" >0.0404</td>
#       <td id="T_33325_row4_col4" class="data row4 col4" >0.8838</td>
#       <td id="T_33325_row4_col5" class="data row4 col5" >1.9182</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_33325_row5_col0" class="data row5 col0" >24.4857</td>
#       <td id="T_33325_row5_col1" class="data row5 col1" >806.4077</td>
#       <td id="T_33325_row5_col2" class="data row5 col2" >28.3973</td>
#       <td id="T_33325_row5_col3" class="data row5 col3" >0.0357</td>
#       <td id="T_33325_row5_col4" class="data row5 col4" >0.8868</td>
#       <td id="T_33325_row5_col5" class="data row5 col5" >1.9022</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_33325_row6_col0" class="data row6 col0" >24.2768</td>
#       <td id="T_33325_row6_col1" class="data row6 col1" >794.7458</td>
#       <td id="T_33325_row6_col2" class="data row6 col2" >28.1912</td>
#       <td id="T_33325_row6_col3" class="data row6 col3" >0.0430</td>
#       <td id="T_33325_row6_col4" class="data row6 col4" >0.8735</td>
#       <td id="T_33325_row6_col5" class="data row6 col5" >1.8314</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_33325_row7_col0" class="data row7 col0" >24.2789</td>
#       <td id="T_33325_row7_col1" class="data row7 col1" >795.4018</td>
#       <td id="T_33325_row7_col2" class="data row7 col2" >28.2029</td>
#       <td id="T_33325_row7_col3" class="data row7 col3" >0.0410</td>
#       <td id="T_33325_row7_col4" class="data row7 col4" >0.8762</td>
#       <td id="T_33325_row7_col5" class="data row7 col5" >1.8642</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_33325_row8_col0" class="data row8 col0" >24.4188</td>
#       <td id="T_33325_row8_col1" class="data row8 col1" >799.4081</td>
#       <td id="T_33325_row8_col2" class="data row8 col2" >28.2738</td>
#       <td id="T_33325_row8_col3" class="data row8 col3" >0.0415</td>
#       <td id="T_33325_row8_col4" class="data row8 col4" >0.8762</td>
#       <td id="T_33325_row8_col5" class="data row8 col5" >1.8198</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_33325_row9_col0" class="data row9 col0" >24.4008</td>
#       <td id="T_33325_row9_col1" class="data row9 col1" >800.4954</td>
#       <td id="T_33325_row9_col2" class="data row9 col2" >28.2930</td>
#       <td id="T_33325_row9_col3" class="data row9 col3" >0.0407</td>
#       <td id="T_33325_row9_col4" class="data row9 col4" >0.8720</td>
#       <td id="T_33325_row9_col5" class="data row9 col5" >1.8082</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_33325_row10_col0" class="data row10 col0" >24.3753</td>
#       <td id="T_33325_row10_col1" class="data row10 col1" >799.6998</td>
#       <td id="T_33325_row10_col2" class="data row10 col2" >28.2789</td>
#       <td id="T_33325_row10_col3" class="data row10 col3" >0.0396</td>
#       <td id="T_33325_row10_col4" class="data row10 col4" >0.8768</td>
#       <td id="T_33325_row10_col5" class="data row10 col5" >1.8554</td>
#     </tr>
#     <tr>
#       <th id="T_33325_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_33325_row11_col0" class="data row11 col0" >0.0718</td>
#       <td id="T_33325_row11_col1" class="data row11 col1" >3.5132</td>
#       <td id="T_33325_row11_col2" class="data row11 col2" >0.0621</td>
#       <td id="T_33325_row11_col3" class="data row11 col3" >0.0024</td>
#       <td id="T_33325_row11_col4" class="data row11 col4" >0.0047</td>
#       <td id="T_33325_row11_col5" class="data row11 col5" >0.0344</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 4e. K-nearest neighbors

# %%
knn = create_model("knn")
# Out:
# <style type="text/css">
# #T_2217d_row10_col0, #T_2217d_row10_col1, #T_2217d_row10_col2, #T_2217d_row10_col3, #T_2217d_row10_col4, #T_2217d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2217d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2217d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2217d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2217d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2217d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2217d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2217d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2217d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2217d_row0_col0" class="data row0 col0" >19.2212</td>
#       <td id="T_2217d_row0_col1" class="data row0 col1" >592.9958</td>
#       <td id="T_2217d_row0_col2" class="data row0 col2" >24.3515</td>
#       <td id="T_2217d_row0_col3" class="data row0 col3" >0.2841</td>
#       <td id="T_2217d_row0_col4" class="data row0 col4" >0.7348</td>
#       <td id="T_2217d_row0_col5" class="data row0 col5" >1.1405</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2217d_row1_col0" class="data row1 col0" >19.6793</td>
#       <td id="T_2217d_row1_col1" class="data row1 col1" >621.6616</td>
#       <td id="T_2217d_row1_col2" class="data row1 col2" >24.9331</td>
#       <td id="T_2217d_row1_col3" class="data row1 col3" >0.2557</td>
#       <td id="T_2217d_row1_col4" class="data row1 col4" >0.7432</td>
#       <td id="T_2217d_row1_col5" class="data row1 col5" >1.1552</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2217d_row2_col0" class="data row2 col0" >19.4864</td>
#       <td id="T_2217d_row2_col1" class="data row2 col1" >605.3452</td>
#       <td id="T_2217d_row2_col2" class="data row2 col2" >24.6038</td>
#       <td id="T_2217d_row2_col3" class="data row2 col3" >0.2725</td>
#       <td id="T_2217d_row2_col4" class="data row2 col4" >0.7379</td>
#       <td id="T_2217d_row2_col5" class="data row2 col5" >1.1431</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2217d_row3_col0" class="data row3 col0" >19.1498</td>
#       <td id="T_2217d_row3_col1" class="data row3 col1" >586.1033</td>
#       <td id="T_2217d_row3_col2" class="data row3 col2" >24.2096</td>
#       <td id="T_2217d_row3_col3" class="data row3 col3" >0.2958</td>
#       <td id="T_2217d_row3_col4" class="data row3 col4" >0.7307</td>
#       <td id="T_2217d_row3_col5" class="data row3 col5" >1.1377</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2217d_row4_col0" class="data row4 col0" >19.1858</td>
#       <td id="T_2217d_row4_col1" class="data row4 col1" >602.4879</td>
#       <td id="T_2217d_row4_col2" class="data row4 col2" >24.5456</td>
#       <td id="T_2217d_row4_col3" class="data row4 col3" >0.2776</td>
#       <td id="T_2217d_row4_col4" class="data row4 col4" >0.7488</td>
#       <td id="T_2217d_row4_col5" class="data row4 col5" >1.2438</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2217d_row5_col0" class="data row5 col0" >19.3355</td>
#       <td id="T_2217d_row5_col1" class="data row5 col1" >598.6123</td>
#       <td id="T_2217d_row5_col2" class="data row5 col2" >24.4666</td>
#       <td id="T_2217d_row5_col3" class="data row5 col3" >0.2842</td>
#       <td id="T_2217d_row5_col4" class="data row5 col4" >0.7506</td>
#       <td id="T_2217d_row5_col5" class="data row5 col5" >1.1850</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2217d_row6_col0" class="data row6 col0" >19.1443</td>
#       <td id="T_2217d_row6_col1" class="data row6 col1" >595.6386</td>
#       <td id="T_2217d_row6_col2" class="data row6 col2" >24.4057</td>
#       <td id="T_2217d_row6_col3" class="data row6 col3" >0.2828</td>
#       <td id="T_2217d_row6_col4" class="data row6 col4" >0.7417</td>
#       <td id="T_2217d_row6_col5" class="data row6 col5" >1.1715</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2217d_row7_col0" class="data row7 col0" >19.1882</td>
#       <td id="T_2217d_row7_col1" class="data row7 col1" >602.0243</td>
#       <td id="T_2217d_row7_col2" class="data row7 col2" >24.5362</td>
#       <td id="T_2217d_row7_col3" class="data row7 col3" >0.2742</td>
#       <td id="T_2217d_row7_col4" class="data row7 col4" >0.7395</td>
#       <td id="T_2217d_row7_col5" class="data row7 col5" >1.1612</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2217d_row8_col0" class="data row8 col0" >19.5385</td>
#       <td id="T_2217d_row8_col1" class="data row8 col1" >619.3561</td>
#       <td id="T_2217d_row8_col2" class="data row8 col2" >24.8869</td>
#       <td id="T_2217d_row8_col3" class="data row8 col3" >0.2574</td>
#       <td id="T_2217d_row8_col4" class="data row8 col4" >0.7421</td>
#       <td id="T_2217d_row8_col5" class="data row8 col5" >1.1243</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2217d_row9_col0" class="data row9 col0" >19.1654</td>
#       <td id="T_2217d_row9_col1" class="data row9 col1" >581.5975</td>
#       <td id="T_2217d_row9_col2" class="data row9 col2" >24.1163</td>
#       <td id="T_2217d_row9_col3" class="data row9 col3" >0.3031</td>
#       <td id="T_2217d_row9_col4" class="data row9 col4" >0.7340</td>
#       <td id="T_2217d_row9_col5" class="data row9 col5" >1.1211</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2217d_row10_col0" class="data row10 col0" >19.3094</td>
#       <td id="T_2217d_row10_col1" class="data row10 col1" >600.5823</td>
#       <td id="T_2217d_row10_col2" class="data row10 col2" >24.5055</td>
#       <td id="T_2217d_row10_col3" class="data row10 col3" >0.2787</td>
#       <td id="T_2217d_row10_col4" class="data row10 col4" >0.7403</td>
#       <td id="T_2217d_row10_col5" class="data row10 col5" >1.1583</td>
#     </tr>
#     <tr>
#       <th id="T_2217d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2217d_row11_col0" class="data row11 col0" >0.1823</td>
#       <td id="T_2217d_row11_col1" class="data row11 col1" >12.1702</td>
#       <td id="T_2217d_row11_col2" class="data row11 col2" >0.2479</td>
#       <td id="T_2217d_row11_col3" class="data row11 col3" >0.0142</td>
#       <td id="T_2217d_row11_col4" class="data row11 col4" >0.0060</td>
#       <td id="T_2217d_row11_col5" class="data row11 col5" >0.0343</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 4f. Ridge Regression

# %%
ridge = create_model("ridge")
# Out:
# <style type="text/css">
# #T_ee2b9_row10_col0, #T_ee2b9_row10_col1, #T_ee2b9_row10_col2, #T_ee2b9_row10_col3, #T_ee2b9_row10_col4, #T_ee2b9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ee2b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee2b9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ee2b9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ee2b9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ee2b9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ee2b9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ee2b9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee2b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee2b9_row0_col0" class="data row0 col0" >24.6021</td>
#       <td id="T_ee2b9_row0_col1" class="data row0 col1" >814.7156</td>
#       <td id="T_ee2b9_row0_col2" class="data row0 col2" >28.5432</td>
#       <td id="T_ee2b9_row0_col3" class="data row0 col3" >0.0165</td>
#       <td id="T_ee2b9_row0_col4" class="data row0 col4" >0.8824</td>
#       <td id="T_ee2b9_row0_col5" class="data row0 col5" >1.8743</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee2b9_row1_col0" class="data row1 col0" >24.7365</td>
#       <td id="T_ee2b9_row1_col1" class="data row1 col1" >821.1596</td>
#       <td id="T_ee2b9_row1_col2" class="data row1 col2" >28.6559</td>
#       <td id="T_ee2b9_row1_col3" class="data row1 col3" >0.0168</td>
#       <td id="T_ee2b9_row1_col4" class="data row1 col4" >0.8845</td>
#       <td id="T_ee2b9_row1_col5" class="data row1 col5" >1.8999</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee2b9_row2_col0" class="data row2 col0" >24.7048</td>
#       <td id="T_ee2b9_row2_col1" class="data row2 col1" >820.1656</td>
#       <td id="T_ee2b9_row2_col2" class="data row2 col2" >28.6385</td>
#       <td id="T_ee2b9_row2_col3" class="data row2 col3" >0.0143</td>
#       <td id="T_ee2b9_row2_col4" class="data row2 col4" >0.8783</td>
#       <td id="T_ee2b9_row2_col5" class="data row2 col5" >1.8557</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ee2b9_row3_col0" class="data row3 col0" >24.7343</td>
#       <td id="T_ee2b9_row3_col1" class="data row3 col1" >819.2574</td>
#       <td id="T_ee2b9_row3_col2" class="data row3 col2" >28.6227</td>
#       <td id="T_ee2b9_row3_col3" class="data row3 col3" >0.0156</td>
#       <td id="T_ee2b9_row3_col4" class="data row3 col4" >0.8831</td>
#       <td id="T_ee2b9_row3_col5" class="data row3 col5" >1.9009</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ee2b9_row4_col0" class="data row4 col0" >24.7012</td>
#       <td id="T_ee2b9_row4_col1" class="data row4 col1" >818.8854</td>
#       <td id="T_ee2b9_row4_col2" class="data row4 col2" >28.6162</td>
#       <td id="T_ee2b9_row4_col3" class="data row4 col3" >0.0182</td>
#       <td id="T_ee2b9_row4_col4" class="data row4 col4" >0.8906</td>
#       <td id="T_ee2b9_row4_col5" class="data row4 col5" >1.9482</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ee2b9_row5_col0" class="data row5 col0" >24.8191</td>
#       <td id="T_ee2b9_row5_col1" class="data row5 col1" >825.4859</td>
#       <td id="T_ee2b9_row5_col2" class="data row5 col2" >28.7313</td>
#       <td id="T_ee2b9_row5_col3" class="data row5 col3" >0.0129</td>
#       <td id="T_ee2b9_row5_col4" class="data row5 col4" >0.8939</td>
#       <td id="T_ee2b9_row5_col5" class="data row5 col5" >1.9343</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ee2b9_row6_col0" class="data row6 col0" >24.6179</td>
#       <td id="T_ee2b9_row6_col1" class="data row6 col1" >813.8433</td>
#       <td id="T_ee2b9_row6_col2" class="data row6 col2" >28.5279</td>
#       <td id="T_ee2b9_row6_col3" class="data row6 col3" >0.0200</td>
#       <td id="T_ee2b9_row6_col4" class="data row6 col4" >0.8805</td>
#       <td id="T_ee2b9_row6_col5" class="data row6 col5" >1.8622</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ee2b9_row7_col0" class="data row7 col0" >24.6220</td>
#       <td id="T_ee2b9_row7_col1" class="data row7 col1" >815.0161</td>
#       <td id="T_ee2b9_row7_col2" class="data row7 col2" >28.5485</td>
#       <td id="T_ee2b9_row7_col3" class="data row7 col3" >0.0174</td>
#       <td id="T_ee2b9_row7_col4" class="data row7 col4" >0.8832</td>
#       <td id="T_ee2b9_row7_col5" class="data row7 col5" >1.8946</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ee2b9_row8_col0" class="data row8 col0" >24.7693</td>
#       <td id="T_ee2b9_row8_col1" class="data row8 col1" >820.0955</td>
#       <td id="T_ee2b9_row8_col2" class="data row8 col2" >28.6373</td>
#       <td id="T_ee2b9_row8_col3" class="data row8 col3" >0.0167</td>
#       <td id="T_ee2b9_row8_col4" class="data row8 col4" >0.8838</td>
#       <td id="T_ee2b9_row8_col5" class="data row8 col5" >1.8505</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ee2b9_row9_col0" class="data row9 col0" >24.7401</td>
#       <td id="T_ee2b9_row9_col1" class="data row9 col1" >820.3885</td>
#       <td id="T_ee2b9_row9_col2" class="data row9 col2" >28.6424</td>
#       <td id="T_ee2b9_row9_col3" class="data row9 col3" >0.0169</td>
#       <td id="T_ee2b9_row9_col4" class="data row9 col4" >0.8792</td>
#       <td id="T_ee2b9_row9_col5" class="data row9 col5" >1.8377</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ee2b9_row10_col0" class="data row10 col0" >24.7047</td>
#       <td id="T_ee2b9_row10_col1" class="data row10 col1" >818.9013</td>
#       <td id="T_ee2b9_row10_col2" class="data row10 col2" >28.6164</td>
#       <td id="T_ee2b9_row10_col3" class="data row10 col3" >0.0165</td>
#       <td id="T_ee2b9_row10_col4" class="data row10 col4" >0.8840</td>
#       <td id="T_ee2b9_row10_col5" class="data row10 col5" >1.8858</td>
#     </tr>
#     <tr>
#       <th id="T_ee2b9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ee2b9_row11_col0" class="data row11 col0" >0.0673</td>
#       <td id="T_ee2b9_row11_col1" class="data row11 col1" >3.3469</td>
#       <td id="T_ee2b9_row11_col2" class="data row11 col2" >0.0585</td>
#       <td id="T_ee2b9_row11_col3" class="data row11 col3" >0.0019</td>
#       <td id="T_ee2b9_row11_col4" class="data row11 col4" >0.0046</td>
#       <td id="T_ee2b9_row11_col5" class="data row11 col5" >0.0345</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ## 5. Output Data

# %%
# Output Full dataset
df.to_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/df_emo_full_pat.csv')

# %%
# Output Train and Test datasets
X_train.to_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/X_train.csv')
X_test.to_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/X_test.csv')
y_train.to_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/y_train.csv')
y_test.to_csv(r'/Users/chaseweber/Desktop/Springboard/Billboard Top 10 Prediction/DataFiles/y_test.csv')

# %% [markdown]
# ## 6. Summary

# %% [markdown]
# In this pre-processing and training step, we have created dummy variables for our categorical data (the song's decade label) and split our data into a train and test set. We will use 70% of the data for training and 30% for testing.
# As an initial exploration, we use PyCaret to analyze which models perform best. We check optimal algorithms using all factors as well as only controlable factors. We run each of these models individually to check that their metrics are consistant across a 10-fold analysis.

# %% [markdown]
# In our next step, we will dig further into these top performing algorithms to create a finalized model that can help us best predict a Song's week position on the Billboard Top 100 chart.

# %%
# Last Update: 2023-03-15
